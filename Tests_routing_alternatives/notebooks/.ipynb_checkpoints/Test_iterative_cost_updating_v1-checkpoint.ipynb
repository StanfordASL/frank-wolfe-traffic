# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Current-Problems" data-toc-modified-id="Current-Problems-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Current Problems</a></span></li><li><span><a href="#Todo:" data-toc-modified-id="Todo:-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Todo:</a></span><ul class="toc-item"><li><span><a href="#Notes" data-toc-modified-id="Notes-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Notes</a></span></li></ul></li><li><span><a href="#Load" data-toc-modified-id="Load-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Load</a></span></li><li><span><a href="#One-directional-problem" data-toc-modified-id="One-directional-problem-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>One directional problem</a></span><ul class="toc-item"><li><span><a href="#Initialize" data-toc-modified-id="Initialize-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Initialize</a></span><ul class="toc-item"><li><span><a href="#Parameters" data-toc-modified-id="Parameters-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Parameters</a></span></li><li><span><a href="#Vizualize-and-theoretical-solution" data-toc-modified-id="Vizualize-and-theoretical-solution-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Vizualize and theoretical solution</a></span></li></ul></li><li><span><a href="#Run" data-toc-modified-id="Run-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Run</a></span><ul class="toc-item"><li><span><a href="#Init-Graph" data-toc-modified-id="Init-Graph-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Init Graph</a></span></li><li><span><a href="#Run" data-toc-modified-id="Run-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Run</a></span></li><li><span><a href="#Analyze-output" data-toc-modified-id="Analyze-output-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Analyze output</a></span></li></ul></li></ul></li><li><span><a href="#Bi-directionnal-problem" data-toc-modified-id="Bi-directionnal-problem-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Bi-directionnal problem</a></span><ul class="toc-item"><li><span><a href="#Initialize" data-toc-modified-id="Initialize-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Initialize</a></span><ul class="toc-item"><li><span><a href="#Parameters" data-toc-modified-id="Parameters-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Parameters</a></span></li><li><span><a href="#Vizualize-and-theoretical-solution" data-toc-modified-id="Vizualize-and-theoretical-solution-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Vizualize and theoretical solution</a></span><ul class="toc-item"><li><span><a href="#Axis-1-to-2" data-toc-modified-id="Axis-1-to-2-5.1.2.1"><span class="toc-item-num">5.1.2.1&nbsp;&nbsp;</span>Axis 1 to 2</a></span></li><li><span><a href="#Axis-2-to-1" data-toc-modified-id="Axis-2-to-1-5.1.2.2"><span class="toc-item-num">5.1.2.2&nbsp;&nbsp;</span>Axis 2 to 1</a></span></li></ul></li><li><span><a href="#Expected-solution" data-toc-modified-id="Expected-solution-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Expected solution</a></span></li></ul></li><li><span><a href="#Run" data-toc-modified-id="Run-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Run</a></span><ul class="toc-item"><li><span><a href="#Init-Graph" data-toc-modified-id="Init-Graph-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Init Graph</a></span></li><li><span><a href="#Run" data-toc-modified-id="Run-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Run</a></span></li><li><span><a href="#Analyze-output" data-toc-modified-id="Analyze-output-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Analyze output</a></span></li></ul></li></ul></li><li><span><a href="#Debug-Line-Search" data-toc-modified-id="Debug-Line-Search-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Debug Line Search</a></span></li><li><span><a href="#Routines-to-implement" data-toc-modified-id="Routines-to-implement-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Routines to implement</a></span></li><li><span><a href="#Useful-nx-lines" data-toc-modified-id="Useful-nx-lines-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Useful nx lines</a></span></li></ul></div>

# %% [markdown]
# # Current Problems

# %% [markdown]
# # Todo:

# %% [markdown]
# - Include good vizualization of the total cost function (from previous MATLAB/Python work) in order to see what the theoretical solution is and to tune your parameters properly (You can use what you have already developed for the previous solution, stored in the vizualization folder)
#
# - Find the good data strcutre to represent the flows over the graph
#
# - Transform Graph into objects, to make it easier to use?
#
# - Stopping criterion for FW
#
# - Introduce node potentials properly (one is the offset for the Demand function, the other one is the potential!

# %% [markdown]
# - Include the vertex potential and the inverse demand shift: two different things!

# %% [markdown]
# ## Notes

# %% [markdown]
# - interesting to note that the algorithm computes the right solution, also for rebalancers, but cannot fulfill it.
# - Actually there is nothing on 1-2p either, which means it does not really work...: THIS IS SOLVED, is was an initialization issue. Makes me confident that the other is also an initialization issue. Which makes sense. At each step, you have to act as if you know all the components (i.e. all the OD pairs)

# %% [markdown]
# - I think it is initialization, it has to be a feasible point.
# - BUT: what is a feasible point when your feasible set evolves over the iterations (essentially, OD pairs in this case)

# %% [markdown]
# - I don't really understand. What does the algorithm do, exactly? It seeks a minimum cost solution that has to respect certain constraints. But here, the constraints are implicit. Therefore, we have to make sure the constraints are always respected, otherwise it will assign zero flow even when there should be flow!! For instance, here, it avoids assigning to 1-R because it does not really need to, you see?

# %% [markdown]
# - Don't forget: the capacities are a mirror for the ri_k
# - think about proper initialization
# - What is the correct way to think about flows? 1. should we split them in m and r? 2. In order to compute the ri_k, I am assuming we should put into it only the flow that goes onto the network (i.e. neglect all the edges that flow directly into dummy node).
# - it seemed like the thing stopped giving the right answer (8.xxx as soon as I introduced a change in the way the ri_k were computed)
# - What is happening is the following: the ALPHA is good at the beginning (first iteration) but then it goes super small for some reason: it does not include the new suggestions.

# %% [markdown]
# # Load

# %%
# %load_ext autoreload
# %autoreload 2
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from routines_icu import *
from helpers_icu import *
import cvxpy as cp
from FW_icu import *

# %% [markdown]
# # One directional problem

# %% [markdown]
# ## Initialize

# %% [markdown]
# ### Parameters

# %%
#parameters
alpha=0.15
beta=4
POTENTIAL_SHIFT=90
INVERSE_DEMAND_SHIFT=80

ZC_EDGE=1

# %%
#to adapt
#to be read from file if necessary

k_list=[10,10,3,10,ZC_EDGE] 
l_list=[10,10,1,10,0]
t_list=[10,10,10,10,ZC_EDGE]
phi_list=[phi(l_list[i],t_list[i]) for i in range(len(l_list))]
is_negative=[0,0,1,0,0]

nodes_pots=[('2_p',POTENTIAL_SHIFT)]

# %% [markdown]
# ### Vizualize and theoretical solution

# %%
x_12=np.linspace(0,N,100)

C1=BPR(phi_list[0],x_12,k_list[0])
C2=-BPR(phi_list[2],x_12,k_list[2])+INVERSE_DEMAND_SHIFT
KK=C1-C2

# %%
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(x_12,C1,label=("C1"))
plt.plot(x_12,C2,label=("C2"))
plt.xlabel("x_12")
plt.ylabel("Cost")
plt.legend()
plt.grid(True)
plt.subplot(1,2,2)
plt.plot(x_12,KK,label="Total Cost")
plt.plot(x_12,np.ones(x_12.shape)*0,'--')
plt.xlabel("x_12")
plt.ylabel("Cost")
plt.grid(True)

# %% [markdown]
# Plot for illustration

# %%
C_T=BPR_int_val(phi_list[0],x_12,k_list[0])+BPR_int_val(phi_list[2],x_12,k_list[2])-INVERSE_DEMAND_SHIFT*x_12

# %%
plt.figure(figsize=(10,5))
plt.plot(x_12,C_T)
plt.grid(True)
plt.xlabel("x_12")
plt.ylabel("Integral Cost")
# Out:
# Text(0, 0.5, 'Integral Cost')

# %% [markdown]
# Compute the optimum with cvxpy

# %%
x_12=cp.Variable()
constraints=[x_12>=0,x_12<=10]

C_T=BPR_int(phi_list[0],x_12,k_list[0])+BPR_int(phi_list[2],x_12,k_list[2])-INVERSE_DEMAND_SHIFT*x_12
prob=cp.Problem(cp.Minimize(C_T),constraints)
prob.solve()
print(prob.status)
print("optimal flow value:", x_12.value)
# Out:
# optimal_inaccurate
# optimal flow value: 8.649843057304913

# %% [markdown]
# ## Run

# %% [markdown]
# ### Init Graph

# %%
G=nx.DiGraph()

nodes_list=['1','2','2_p','R']
edge_list=[('1','2'),('2','1'),('2','2_p'),('1','R'),('1','2_p')]

G.add_nodes_from(nodes_list)
G.add_edges_from(edge_list)

OD=dict()
N=10
OD[('1','2_p')]=N
OD[('2','R')]=N

print(OD)
# Out:
# {('1', '2_p'): 10, ('2', 'R'): 10}

# %%
G=initEdgeAttr(G,edge_list,k_list,phi_list,is_negative)
G=initNodeAttr(G,nodes_pots)
G=update_costs(G,INVERSE_DEMAND_SHIFT)

#Create a feasible solution for the passengers
G=init_flows(G,OD) 

for e in G.edges():
    print(e," --- ",G.edges[e])

G=update_costs(G,INVERSE_DEMAND_SHIFT)

# #update the ri_k
# ri_k,G=estimate_ri_k(G,dummy_nodes)
# print(ri_k)
#update OD
# OD=update_OD(OD,ri_k,dummy_nodes)
# print(OD)


# #Create a feasible solution for the rebalancers
#but careful with the initialization
# G=init_flows(G,OD,1)



dummy_nodes=dict()
dummy_nodes['2_p']='2'


print(G.nodes.data())

for e in G.edges():
    print(e," --- ",G.edges[e])
# Out:
# ('1', '2')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 10, 'f_r': 0, 'cost': 36.0}
# ('1', 'R')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 0, 'f_r': 10, 'cost': 36.0}
# ('1', '2_p')  ---  {'k': 1, 'phi': 0.0, 'sign': 1, 'f_m': 0, 'f_r': 0, 'cost': 90.0}
# ('2', '1')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 0, 'f_r': 10, 'cost': 36.0}
# ('2', '2_p')  ---  {'k': 3, 'phi': 3.6, 'sign': -1, 'f_m': 10, 'f_r': 0, 'cost': 13.599999999999994}
# [('1', {'ri': 0}), ('2', {'ri': 0}), ('2_p', {'pot': 90, 'ri': 0}), ('R', {'ri': 0})]
# ('1', '2')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 10, 'f_r': 0, 'cost': 41.4}
# ('1', 'R')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 0, 'f_r': 10, 'cost': 41.4}
# ('1', '2_p')  ---  {'k': 1, 'phi': 0.0, 'sign': 1, 'f_m': 0, 'f_r': 0, 'cost': 90.0}
# ('2', '1')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 0, 'f_r': 10, 'cost': 41.4}
# ('2', '2_p')  ---  {'k': 3, 'phi': 3.6, 'sign': -1, 'f_m': 10, 'f_r': 0, 'cost': 80.26666666666668}

# %% [markdown]
# ### Run

# %%
G_k,y_list,OD=FW(G,OD,edge_list,dummy_nodes)
# Out:
# ###############################
# iteration #  1
# oD: {('1', '2_p'): 10, ('2', 'R'): 10, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.13672495757101827
# ###############################
# iteration #  2
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.632750424289817, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.99950109954242
# ###############################
# iteration #  3
# oD: {('1', '2_p'): 10, ('2', 'R'): 9.999317878561053, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.09065874593718468
# ###############################
# iteration #  4
# oD: {('1', '2_p'): 10, ('2', 'R'): 9.092792259463438, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.03894358181265262
# ###############################
# iteration #  5
# ...

# %%
OD
# Out:
# {('1', '2_p'): 10,
#  ('2', 'R'): 8.600937631548184,
#  ('1', 'R'): 0,
#  ('2_p', 'R'): 0}

# %%
print_final_flows(G_k)
# Out:
# ('1', '2')  :  8.73351553584862
# ('1', 'R')  :  8.623148414995295
# ('1', '2_p')  :  1.2664844641513797
# ('2', '1')  :  8.623148414995295
# ('2', '2_p')  :  8.73351553584862

# %%
print_final_cost(G_k)
# Out:
# ('1', '2')  :  39.14159464788482
# ('1', 'R')  :  41.455995577705075
# ('1', '2_p')  :  90.0
# ('2', '1')  :  38.98577586692724
# ('2', '2_p')  :  52.385119109689185

# %% [markdown]
# ### Analyze output

# %%
attrs=['f_m', 'f_r','cost','k', 'y_m','y_r']
plot_edge_attrs(G_k,y_list,attrs)

# %%
plot_node_attrs(G_k,['ri'])

# %% [markdown]
# # Bi-directionnal problem

# %% [markdown]
# ## Initialize

# %% [markdown]
# ### Parameters

# %%
#parameters
alpha=0.15
beta=4
POTENTIAL_SHIFT=90
INVERSE_DEMAND_SHIFT=80

ZC_EDGE=1

# %%
#to adapt
#to be read from file if necessary
nodes_list=['1','2','2_p','R','1_p']
edge_list=[('1','2'),('2','1'),('2','2_p'),('1','R'),('1','2_p'),('1','1_p'),('2','1_p'),('2','R')]
k_list=[10,10,3,10,ZC_EDGE,2,ZC_EDGE,10] 
l_list=[10,10,1,100,0,1,0,100]
t_list=[10,10,10,10,ZC_EDGE,10,ZC_EDGE,10]
phi_list=[phi(l_list[i],t_list[i]) for i in range(len(l_list))]
is_negative=[0,0,1,0,0,1,0,0]

nodes_pots=[('2_p',POTENTIAL_SHIFT),('1_p',POTENTIAL_SHIFT)]

# %%
OD=dict()
N=10
OD[('1','2_p')]=N
OD[('2','R')]=N
OD[('2','1_p')]=N
OD[('1','R')]=N

print(OD)
# Out:
# {('1', '2_p'): 10, ('2', 'R'): 10, ('2', '1_p'): 10, ('1', 'R'): 10}

# %% [markdown]
# ### Vizualize and theoretical solution

# %% [markdown]
# #### Axis 1 to 2

# %%
x_12=np.linspace(0,N,100)

C1=BPR(phi_list[0],x_12,k_list[0])
C2=-BPR(phi_list[2],x_12,k_list[2])+INVERSE_DEMAND_SHIFT
KK=C1-C2

# %%
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(x_12,C1,label=("C1"))
plt.plot(x_12,C2,label=("C2"))
plt.xlabel("x_12")
plt.ylabel("Cost")
plt.legend()
plt.grid(True)
plt.subplot(1,2,2)
plt.plot(x_12,KK,label="Total Cost")
plt.plot(x_12,np.ones(x_12.shape)*0,'--')
plt.xlabel("x_12")
plt.ylabel("Cost")
plt.grid(True)

# %% [markdown]
# Plot for illustration

# %%
C_T=BPR_int_val(phi_list[0],x_12,k_list[0])+BPR_int_val(phi_list[2],x_12,k_list[2])-INVERSE_DEMAND_SHIFT*x_12

# %%
plt.figure(figsize=(10,5))
plt.plot(x_12,C_T)
plt.grid(True)
plt.xlabel("x_12")
plt.ylabel("Integral Cost")
# Out:
# Text(0, 0.5, 'Integral Cost')

# %% [markdown]
# Compute the optimum with cvxpy

# %%
x_12=cp.Variable()
constraints=[x_12>=0,x_12<=10]

C_T=BPR_int(phi_list[0],x_12,k_list[0])+BPR_int(phi_list[2],x_12,k_list[2])-INVERSE_DEMAND_SHIFT*x_12
prob=cp.Problem(cp.Minimize(C_T),constraints)
prob.solve()
print(prob.status)
print("optimal flow value:", x_12.value)
# Out:
# optimal_inaccurate
# optimal flow value: 8.649843057304913

# %% [markdown]
# #### Axis 2 to 1

# %%
x_21=np.linspace(0,N,100)

C1=BPR(phi_list[1],x_12,k_list[1])
C2=-BPR(phi_list[5],x_12,k_list[5])+INVERSE_DEMAND_SHIFT
KK=C1-C2

# %%
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(x_21,C1,label=("C1"))
plt.plot(x_21,C2,label=("C2"))
plt.xlabel("x_21")
plt.ylabel("Cost")
plt.legend()
plt.grid(True)
plt.subplot(1,2,2)
plt.plot(x_21,KK,label="Total Cost")
plt.plot(x_21,np.ones(x_21.shape)*0,'--')
plt.xlabel("x_21")
plt.ylabel("Cost")
plt.grid(True)

# %% [markdown]
# Plot for illustration

# %%
C_T=BPR_int_val(phi_list[1],x_21,k_list[1])+BPR_int_val(phi_list[5],x_21,k_list[5])-INVERSE_DEMAND_SHIFT*x_21

# %%
plt.figure(figsize=(10,5))
plt.plot(x_21,C_T)
plt.grid(True)
plt.xlabel("x_12")
plt.ylabel("Integral Cost")
# Out:
# Text(0, 0.5, 'Integral Cost')

# %% [markdown]
# Compute the optimum with cvxpy

# %%
x_21=cp.Variable()
constraints=[x_21>=0,x_21<=10]

C_T=BPR_int(phi_list[1],x_21,k_list[1])+BPR_int(phi_list[5],x_21,k_list[5])-INVERSE_DEMAND_SHIFT*x_21
prob=cp.Problem(cp.Minimize(C_T),constraints)
prob.solve()
print(prob.status)
print("optimal flow value:", x_21.value)
# Out:
# optimal
# optimal flow value: 5.858557569350867

# %% [markdown]
# ### Expected solution

# %% [markdown]
# As per the viz, we should have at equilibrium
# - x_12 ~ 8.65
# - x_21_m ~ 5.85
# - x_21_r ~ 2.8

# %% [markdown]
# ## Run

# %% [markdown]
# ### Init Graph

# %%
OD=dict()
N=10
OD[('1','2_p')]=N
OD[('2','1_p')]=N
# OD[('1','R')]=N
# OD[('2','R')]=N

print(OD)
# Out:
# {('1', '2_p'): 10, ('2', '1_p'): 10}

# %%
G=nx.DiGraph()
G.add_nodes_from(nodes_list)
G.add_edges_from(edge_list)

print(OD)
# Out:
# {('1', '2_p'): 10, ('2', '1_p'): 10}

# %%
G=initEdgeAttr(G,edge_list,k_list,phi_list,is_negative)
G=initNodeAttr(G,nodes_pots)
G=update_costs(G,INVERSE_DEMAND_SHIFT)

#Create a feasible solution for the passengers
G=init_flows2(G,OD) 

for e in G.edges():
    print(e," --- ",G.edges[e])

G=update_costs(G,INVERSE_DEMAND_SHIFT)

# #update the ri_k
# ri_k,G=estimate_ri_k(G,dummy_nodes)
# print(ri_k)
#update OD
# OD=update_OD(OD,ri_k,dummy_nodes)
# print(OD)


# #Create a feasible solution for the rebalancers
#but careful with the initialization
# G=init_flows(G,OD,1)



dummy_nodes=dict()
dummy_nodes['2_p']='2'
dummy_nodes['1_p']='1'


print(G.nodes.data())

for e in G.edges():
    print(e," --- ",G.edges[e])
# Out:
# ('1', '2')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 10, 'f_r': 0, 'cost': 36.0}
# ('1', 'R')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 0, 'f_r': 0, 'cost': 36.0}
# ('1', '2_p')  ---  {'k': 1, 'phi': 0.0, 'sign': 1, 'f_m': 0, 'f_r': 0, 'cost': 90.0}
# ('1', '1_p')  ---  {'k': 2, 'phi': 3.6, 'sign': -1, 'f_m': 10, 'f_r': 0, 'cost': 13.599999999999994}
# ('2', '1')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 10, 'f_r': 0, 'cost': 36.0}
# ('2', '2_p')  ---  {'k': 3, 'phi': 3.6, 'sign': -1, 'f_m': 10, 'f_r': 0, 'cost': 13.599999999999994}
# ('2', '1_p')  ---  {'k': 1, 'phi': 0.0, 'sign': 1, 'f_m': 0, 'f_r': 0, 'cost': 90.0}
# ('2', 'R')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 0, 'f_r': 0, 'cost': 36.0}
# [('1', {'ri': 0}), ('2', {'ri': 0}), ('2_p', {'pot': 90, 'ri': 0}), ('R', {'ri': 0}), ('1_p', {'pot': 90, 'ri': 0})]
# ('1', '2')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 10, 'f_r': 0, 'cost': 41.4}
# ...

# %%
print(OD)
# Out:
# {('1', '2_p'): 10, ('2', '1_p'): 10}

# %% [markdown]
# ### Run

# %% [markdown]
# Even if the cost is super super high, the edge 2-R has flow. Does not make sense, absolutely does not make sense

# %% [markdown]
# It worked before I changed how to update capacities (basically, if ri_k <eps nothing happened)

# %% [markdown]
# Maybe due to an impossibility by the solver to evaluate things. YES! The solver cannot handle too high values: you just skip those edges in the total cost basically

# %% [markdown]
# There are going to be infinite edges (infinite costs because of infinite capacities)

# %%
G_k,y_list,obj_list,OD=FW(G,OD,edge_list,dummy_nodes)
# Out:
# ###############################
# iteration #  1
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  41.4  ---  80.26666666666668
# Cost for normal edge (1,2,2_p):  121.66666666666669
# Cost for 1-R:  10000000000000000000000
# Cost for 2-R:  10000000000000000000000
# oD: {('1', '2_p'): 10, ('2', '1_p'): 10, ('1', 'R'): 0, ('2', 'R'): 0, ('2_p', 'R'): 0, ('1_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# ...

# %%
OD
# Out:
# {('1', '2_p'): 10,
#  ('2', '1_p'): 10,
#  ('1', 'R'): 0,
#  ('2', 'R'): 1.679116763394573,
#  ('2_p', 'R'): 0,
#  ('1_p', 'R'): 0}

# %%
print_final_flows(G_k)
# Out:
# ('1', '2')  :  7.447079830235915
# ('1', 'R')  :  0.12889689988857606
# ('1', '2_p')  :  2.5529201697640853
# ('1', '1_p')  :  5.768063549498146
# ('2', '1')  :  5.8969604493867225
# ('2', '2_p')  :  7.447079830235915
# ('2', '1_p')  :  4.231936450501854
# ('2', 'R')  :  0.0

# %%
print_final_cost(G_k)
# Out:
# ('1', '2')  :  37.66074195535667
# ('1', 'R')  :  36.00018697746166
# ('1', '2_p')  :  90.0
# ('1', '1_p')  :  50.95232549497979
# ('2', '1')  :  36.652836875258444
# ('2', '2_p')  :  34.1029871031688
# ('2', '1_p')  :  90.0
# ('2', 'R')  :  10000000000000000000000

# %%
sanity_check_N(G_k)
# Out:
# 1 to 2:  10.0
# 2 to 1:  10.0

# %%
sanity_check_cost(G_k)
# Out:
# 1 to 2:  90.0  =====  71.76372905852547
# 2 to 1:  90.0  =====  87.60516237023823

# %%
def sanity_check_N(G_k):
    G_end=G_k[-1]
    print("1 to 2: ", G_end['1']['2_p']['f_m']+G_end['1']['2']['f_m'])
    print("2 to 1: ", G_end['2']['1_p']['f_m']+G_end['2']['1']['f_m'])
            
            
def sanity_check_cost(G_k):
    G_end=G_k[-1]
    print("1 to 2: ", G_end['1']['2_p']['cost']," ===== ", G_end['1']['2']['cost']+G_end['2']['2_p']['cost'])
    print("2 to 1: ", G_end['2']['1_p']['cost']," ===== ", G_end['2']['1']['cost']+G_end['1']['1_p']['cost'])

# %% [markdown]
# It seems to compute the right equilibrium points but not to redirect the rebalancers properly, becuase the capacities are not well updated basically. This was before I updated anything in the way the capacities were updated

# %% [markdown]
# ### Analyze output

# %% [markdown]
# Debug 2D:
# - I don't understand why there is rebalancing: SOLVED: There is rebalancing because of the initialization. In the initialization, you assign currently vehicles on the R edges, and they are therefore scaled that way
# - I don't understand why it cannot find 3 and 5 but rather settles for the intermediate point
#
# Actually, is the Debug 2D a good way to debug? Because the stationnary point will be not necessarily a point where all paths are equal in cost (as it assigns based on shortest path...)

# %%
#plot also the theoretical lines (what should the result be, theoretically?)

# %%
attrs=['f_m', 'f_r','cost','k', 'y_m','y_r']
plot_edge_attrs(G_k,y_list,attrs)

# %%
plot_node_attrs(G_k,['ri'])

# %%
plt.figure(figsize=(10,5))
plt.plot(np.array(obj_list),'--o')
plt.grid(True)
plt.ylabel("obj value")
plt.xlabel("iteration #")
# Out:
# Text(0.5, 0, 'iteration #')

# %% [markdown]
# # Debug Line Search

# %% [markdown]
# - It started working when removing the node potential from the toal cost. Any explanation? Should we remove it or not?

# %% [markdown]
# # Routines to implement

# %%
# def stopping_criterion(x_k,y_k):

# %% [markdown]
# # Useful nx lines

# %%
nx.get_edge_attributes(G,'f')
# Out:
# {('1', '2'): 0, ('1', 'R'): 0, ('2', '1'): 0, ('2', '2_p'): 0}

# %%
G.nodes.data()
# Out:
# NodeDataView({'1': {}, '2': {}, '2_p': {'pot': 90}, 'R': {}})

# %%
G.edges.data()
# Out:
# OutEdgeDataView([('1', '2', {'k': 1, 'phi': 36.0, 'sign': 1, 'f': 0, 'cost': 36.0}), ('1', 'R', {'k': 10, 'phi': 36.0, 'sign': 1, 'f': 0, 'cost': 36.0}), ('2', '1', {'k': 10, 'phi': 36.0, 'sign': 1, 'f': 0, 'cost': 36.0}), ('2', '2_p', {'k': 10, 'phi': 36.0, 'sign': -1, 'f': 0, 'cost': -36.0})])

# %%
G['1']['2']
# Out:
# {'f': 0, 'k': 1, 'phi': 36.0, 'sign': 1, 'cost': 36.0}
