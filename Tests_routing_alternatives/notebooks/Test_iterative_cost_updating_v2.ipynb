# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Current-Problems" data-toc-modified-id="Current-Problems-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Current Problems</a></span></li><li><span><a href="#Todo:" data-toc-modified-id="Todo:-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Todo:</a></span><ul class="toc-item"><li><span><a href="#Notes" data-toc-modified-id="Notes-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Notes</a></span></li></ul></li><li><span><a href="#Load" data-toc-modified-id="Load-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Load</a></span></li><li><span><a href="#One-directional-problem" data-toc-modified-id="One-directional-problem-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>One directional problem</a></span><ul class="toc-item"><li><span><a href="#Initialize" data-toc-modified-id="Initialize-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Initialize</a></span><ul class="toc-item"><li><span><a href="#Parameters" data-toc-modified-id="Parameters-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Parameters</a></span></li><li><span><a href="#Vizualize-and-theoretical-solution" data-toc-modified-id="Vizualize-and-theoretical-solution-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Vizualize and theoretical solution</a></span></li></ul></li><li><span><a href="#Run" data-toc-modified-id="Run-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Run</a></span><ul class="toc-item"><li><span><a href="#Init-Graph" data-toc-modified-id="Init-Graph-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Init Graph</a></span></li><li><span><a href="#Run" data-toc-modified-id="Run-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Run</a></span></li><li><span><a href="#Analyze-output" data-toc-modified-id="Analyze-output-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Analyze output</a></span></li></ul></li></ul></li><li><span><a href="#Bi-directionnal-problem" data-toc-modified-id="Bi-directionnal-problem-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Bi-directionnal problem</a></span><ul class="toc-item"><li><span><a href="#Initialize" data-toc-modified-id="Initialize-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Initialize</a></span><ul class="toc-item"><li><span><a href="#Parameters" data-toc-modified-id="Parameters-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Parameters</a></span></li><li><span><a href="#Vizualize-and-theoretical-solution" data-toc-modified-id="Vizualize-and-theoretical-solution-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Vizualize and theoretical solution</a></span><ul class="toc-item"><li><span><a href="#Axis-1-to-2" data-toc-modified-id="Axis-1-to-2-5.1.2.1"><span class="toc-item-num">5.1.2.1&nbsp;&nbsp;</span>Axis 1 to 2</a></span></li><li><span><a href="#Axis-2-to-1" data-toc-modified-id="Axis-2-to-1-5.1.2.2"><span class="toc-item-num">5.1.2.2&nbsp;&nbsp;</span>Axis 2 to 1</a></span></li></ul></li><li><span><a href="#Expected-solution" data-toc-modified-id="Expected-solution-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Expected solution</a></span></li></ul></li><li><span><a href="#Run" data-toc-modified-id="Run-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Run</a></span><ul class="toc-item"><li><span><a href="#Init-Graph" data-toc-modified-id="Init-Graph-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Init Graph</a></span></li><li><span><a href="#Run" data-toc-modified-id="Run-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Run</a></span></li><li><span><a href="#Analyze-output" data-toc-modified-id="Analyze-output-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Analyze output</a></span></li></ul></li></ul></li><li><span><a href="#Understand-the-oscillations-around-0" data-toc-modified-id="Understand-the-oscillations-around-0-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Understand the oscillations around 0</a></span></li><li><span><a href="#Debug-Line-Search" data-toc-modified-id="Debug-Line-Search-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Debug Line Search</a></span></li><li><span><a href="#Routines-to-implement" data-toc-modified-id="Routines-to-implement-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Routines to implement</a></span></li><li><span><a href="#Useful-nx-lines" data-toc-modified-id="Useful-nx-lines-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Useful nx lines</a></span></li></ul></div>

# %% [markdown]
# # Current Problems

# %% [markdown]
# # Todo:

# %% [markdown]
# - Include good vizualization of the total cost function (from previous MATLAB/Python work) in order to see what the theoretical solution is and to tune your parameters properly (You can use what you have already developed for the previous solution, stored in the vizualization folder)
#
# - Find the good data strcutre to represent the flows over the graph
#
# - Transform Graph into objects, to make it easier to use?
#
# - Stopping criterion for FW
#
# - Introduce node potentials properly (one is the offset for the Demand function, the other one is the potential!

# %% [markdown]
# - Include the vertex potential and the inverse demand shift: two different things!

# %% [markdown]
# ## Notes

# %% [markdown]
# - interesting to note that the algorithm computes the right solution, also for rebalancers, but cannot fulfill it.
# - Actually there is nothing on 1-2p either, which means it does not really work...: THIS IS SOLVED, is was an initialization issue. Makes me confident that the other is also an initialization issue. Which makes sense. At each step, you have to act as if you know all the components (i.e. all the OD pairs)

# %% [markdown]
# - I think it is initialization, it has to be a feasible point.
# - BUT: what is a feasible point when your feasible set evolves over the iterations (essentially, OD pairs in this case)

# %% [markdown]
# - I don't really understand. What does the algorithm do, exactly? It seeks a minimum cost solution that has to respect certain constraints. But here, the constraints are implicit. Therefore, we have to make sure the constraints are always respected, otherwise it will assign zero flow even when there should be flow!! For instance, here, it avoids assigning to 1-R because it does not really need to, you see?

# %% [markdown]
# - Don't forget: the capacities are a mirror for the ri_k
# - think about proper initialization
# - What is the correct way to think about flows? 1. should we split them in m and r? 2. In order to compute the ri_k, I am assuming we should put into it only the flow that goes onto the network (i.e. neglect all the edges that flow directly into dummy node).
# - it seemed like the thing stopped giving the right answer (8.xxx as soon as I introduced a change in the way the ri_k were computed)
# - What is happening is the following: the ALPHA is good at the beginning (first iteration) but then it goes super small for some reason: it does not include the new suggestions.

# %% [markdown]
# # Load

# %%
# %load_ext autoreload
# %autoreload 2
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from routines_icu import *
from helpers_icu import *
import cvxpy as cp
from FW_icu import *

# %% [markdown]
# # One directional problem

# %% [markdown]
# ## Initialize

# %% [markdown]
# ### Parameters

# %%
#parameters
alpha=0.15
beta=4
POTENTIAL_SHIFT=90
INVERSE_DEMAND_SHIFT=80

ZC_EDGE=1

# %%
#to adapt
#to be read from file if necessary

k_list=[10,10,3,10,ZC_EDGE] 
l_list=[10,10,1,10,0]
t_list=[10,10,10,10,ZC_EDGE]
phi_list=[phi(l_list[i],t_list[i]) for i in range(len(l_list))]
is_negative=[0,0,1,0,0]

nodes_pots=[('2_p',POTENTIAL_SHIFT)]

# %% [markdown]
# ### Vizualize and theoretical solution

# %%
x_12=np.linspace(0,N,100)

C1=BPR(phi_list[0],x_12,k_list[0])
C2=-BPR(phi_list[2],x_12,k_list[2])+INVERSE_DEMAND_SHIFT
KK=C1-C2

# %%
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(x_12,C1,label=("C1"))
plt.plot(x_12,C2,label=("C2"))
plt.xlabel("x_12")
plt.ylabel("Cost")
plt.legend()
plt.grid(True)
plt.subplot(1,2,2)
plt.plot(x_12,KK,label="Total Cost")
plt.plot(x_12,np.ones(x_12.shape)*0,'--')
plt.xlabel("x_12")
plt.ylabel("Cost")
plt.grid(True)

# %% [markdown]
# Plot for illustration

# %%
C_T=BPR_int_val(phi_list[0],x_12,k_list[0])+BPR_int_val(phi_list[2],x_12,k_list[2])-INVERSE_DEMAND_SHIFT*x_12

# %%
plt.figure(figsize=(10,5))
plt.plot(x_12,C_T)
plt.grid(True)
plt.xlabel("x_12")
plt.ylabel("Integral Cost")
# Out:
# Text(0, 0.5, 'Integral Cost')

# %% [markdown]
# Compute the optimum with cvxpy

# %%
x_12=cp.Variable()
constraints=[x_12>=0,x_12<=10]

C_T=BPR_int(phi_list[0],x_12,k_list[0])+BPR_int(phi_list[2],x_12,k_list[2])-INVERSE_DEMAND_SHIFT*x_12
prob=cp.Problem(cp.Minimize(C_T),constraints)
prob.solve()
print(prob.status)
print("optimal flow value:", x_12.value)
# Out:
# optimal_inaccurate
# optimal flow value: 8.649843057304913

# %% [markdown]
# ## Run

# %% [markdown]
# ### Init Graph

# %%
G=nx.DiGraph()

nodes_list=['1','2','2_p','R']
edge_list=[('1','2'),('2','1'),('2','2_p'),('1','R'),('1','2_p')]

G.add_nodes_from(nodes_list)
G.add_edges_from(edge_list)

OD=dict()
N=10
OD[('1','2_p')]=N
OD[('2','R')]=N

print(OD)
# Out:
# {('1', '2_p'): 10, ('2', 'R'): 10}

# %%
G=initEdgeAttr(G,edge_list,k_list,phi_list,is_negative)
G=initNodeAttr(G,nodes_pots)
G=update_costs(G,INVERSE_DEMAND_SHIFT)

#Create a feasible solution for the passengers
G=init_flows(G,OD) 

for e in G.edges():
    print(e," --- ",G.edges[e])

G=update_costs(G,INVERSE_DEMAND_SHIFT)

# #update the ri_k
# ri_k,G=estimate_ri_k(G,dummy_nodes)
# print(ri_k)
#update OD
# OD=update_OD(OD,ri_k,dummy_nodes)
# print(OD)


# #Create a feasible solution for the rebalancers
#but careful with the initialization
# G=init_flows(G,OD,1)



dummy_nodes=dict()
dummy_nodes['2_p']='2'


print(G.nodes.data())

for e in G.edges():
    print(e," --- ",G.edges[e])
# Out:
# ('1', '2')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 10, 'f_r': 0, 'cost': 36.0}
# ('1', 'R')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 0, 'f_r': 10, 'cost': 36.0}
# ('1', '2_p')  ---  {'k': 1, 'phi': 0.0, 'sign': 1, 'f_m': 0, 'f_r': 0, 'cost': 90.0}
# ('2', '1')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 0, 'f_r': 10, 'cost': 36.0}
# ('2', '2_p')  ---  {'k': 3, 'phi': 3.6, 'sign': -1, 'f_m': 10, 'f_r': 0, 'cost': 13.599999999999994}
# [('1', {'ri': 0}), ('2', {'ri': 0}), ('2_p', {'pot': 90, 'ri': 0}), ('R', {'ri': 0})]
# ('1', '2')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 10, 'f_r': 0, 'cost': 41.4}
# ('1', 'R')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 0, 'f_r': 10, 'cost': 41.4}
# ('1', '2_p')  ---  {'k': 1, 'phi': 0.0, 'sign': 1, 'f_m': 0, 'f_r': 0, 'cost': 90.0}
# ('2', '1')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 0, 'f_r': 10, 'cost': 41.4}
# ('2', '2_p')  ---  {'k': 3, 'phi': 3.6, 'sign': -1, 'f_m': 10, 'f_r': 0, 'cost': 80.26666666666668}

# %% [markdown]
# ### Run

# %%
G_k,y_list,OD=FW(G,OD,edge_list,dummy_nodes)
# Out:
# ###############################
# iteration #  1
# oD: {('1', '2_p'): 10, ('2', 'R'): 10, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.13672495757101827
# ###############################
# iteration #  2
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.632750424289817, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.99950109954242
# ###############################
# iteration #  3
# oD: {('1', '2_p'): 10, ('2', 'R'): 9.999317878561053, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.09065874593718468
# ###############################
# iteration #  4
# oD: {('1', '2_p'): 10, ('2', 'R'): 9.092792259463438, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.03894358181265262
# ###############################
# iteration #  5
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.73868636020157, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.015291340870998229
# ###############################
# iteration #  6
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.605060128302984, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.3527722397611969
# ###############################
# iteration #  7
# oD: {('1', '2_p'): 10, ('2', 'R'): 9.097156191173736, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.031982944766793475
# ###############################
# iteration #  8
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.806202347176534, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.021605698524377926
# ###############################
# iteration #  9
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.615938194118769, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.25913949269089037
# ###############################
# iteration #  10
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.97460326834767, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.028315814297131252
# ###############################
# iteration #  11
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.72048006881071, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.013027358846178842
# ###############################
# iteration #  12
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.606875245643362, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.2436345767623319
# ###############################
# iteration #  13
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.946288605548169, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.02491175204213299
# ###############################
# iteration #  14
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.723420882109393, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.008776212655867137
# ###############################
# iteration #  15
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.646862285361369, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.1097301519421229
# ###############################
# iteration #  16
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.795342292387282, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.012870521344659248
# ###############################
# iteration #  17
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.682141651679528, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.009257225906605835
# ###############################
# iteration #  18
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.601769105056778, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.22164307068733977
# ###############################
# iteration #  19
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.911677294141901, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.02308802831585362
# ###############################
# iteration #  20
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.705924236433003, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.011836320841472773
# ###############################
# iteration #  21
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.602878123949028, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.19591152340928739
# ###############################
# iteration #  22
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.876590399074615, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.02047786659354185
# ###############################
# iteration #  23
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.694816765076851, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.005781348360331785
# ###############################
# iteration #  24
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.64454900042869, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.06322423537262288
# ###############################
# iteration #  25
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.730246353461643, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.013062463272418712
# ###############################
# iteration #  26
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.616207831110383, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.14237663375475668
# ###############################
# iteration #  27
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.813227501933081, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.016578203566706595
# ###############################
# iteration #  28
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.667120022326337, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.007883295169520337
# ###############################
# iteration #  29
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.598794556920678, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.18016020051371465
# ###############################
# iteration #  30
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.851236010506756, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.018192851239298185
# ###############################
# iteration #  31
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.690206790483687, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.010045832155756492
# ###############################
# iteration #  32
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.602906431667673, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.15443126781598995
# ###############################
# iteration #  33
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.8186613626828, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.016130495712180455
# ###############################
# iteration #  34
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.676411983384874, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.00871104508760929
# ###############################
# iteration #  35
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.600831367398934, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.15674230967802238
# ###############################
# iteration #  36
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.820140290501865, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.015913087883038395
# ###############################
# iteration #  37
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.679784622918381, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.00888473228801792
# ###############################
# iteration #  38
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.602667060226096, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.09331690598207952
# ###############################
# iteration #  39
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.73306184679264, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.011673341904124187
# ###############################
# iteration #  40
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.631117829985168, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.06538332082882574
# ###############################
# iteration #  41
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.720619892084107, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.011076813827654767
# ###############################
# iteration #  42
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.624023209077748, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.06708517998949022
# ###############################
# iteration #  43
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.716330859758129, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.00583545807263439
# ###############################
# iteration #  44
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.665467076478802, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.0027893712120792852
# ###############################
# iteration #  45
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.641295872076451, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.02214215221670644
# ###############################
# iteration #  46
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.671380505694403, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.0006921062278335769
# ###############################
# iteration #  47
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.665378989242496, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.0075826559121668574
# ###############################
# iteration #  48
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.59967240201855, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.11406783135576244
# ###############################
# iteration #  49
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.759404734307918, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.012512975519095457
# ###############################
# iteration #  50
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.649798517305674, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.005238848388059636
# ###############################
# iteration #  51
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.656872018166844, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.006796568624330088
# ###############################
# iteration #  52
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.59803499342333, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.10127350968059977
# ###############################
# iteration #  53
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.740016910088734, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.011616447312487118
# ###############################
# iteration #  54
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.638488964142441, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.011562563686761802
# ###############################
# iteration #  55
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.654231522204773, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.006497679873124411
# ###############################
# iteration #  56
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.597999096225584, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.08805119280219707
# ###############################
# iteration #  57
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.72144694811268, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.010563296918738434
# ###############################
# iteration #  58
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.62931971443874, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.03281779939205789
# ###############################
# iteration #  59
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.674302425080938, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.003010766955416738
# ###############################
# iteration #  60
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.648186121978213, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.0025329078482226527
# ###############################
# iteration #  61
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.65161014195919, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.0010250884285590899
# ###############################
# iteration #  62
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.652992360799855, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.006326476961698729
# ###############################
# iteration #  63
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.5982494039795, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.10829516985009495
# ###############################
# iteration #  64
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.750052222863012, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.01160463260310007
# ###############################
# iteration #  65
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.648511081558748, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.0013108304354171572
# ###############################
# iteration #  66
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.65028265436617, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.0008505801762469986
# ###############################
# iteration #  67
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.651430697183903, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.005488502831535432
# ###############################
# iteration #  68
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.658832323620931, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.0019355360477014173
# ###############################
# iteration #  69
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.642072841527561, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.007149289061023343
# ###############################
# iteration #  70
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.651781055307294, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.00543515711031717
# ###############################
# iteration #  71
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.659108837090805, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.006735733418762597
# ###############################
# iteration #  72
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.60078338832011, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.10506075325393231
# ###############################
# iteration #  73
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.747786139508614, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.011419488756710762
# ###############################
# iteration #  74
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.647890894042385, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.0011462911971832515
# ###############################
# iteration #  75
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.649440804808176, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.005876070647299684
# ###############################
# iteration #  76
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.657376786052483, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.0017875182852990998
# ###############################
# iteration #  77
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.64190156674469, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.005588714062134997
# ###############################
# iteration #  78
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.649491590556387, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.005974811075036565
# ###############################
# iteration #  79
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.65756062315806, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.0065623501127822885
# ###############################
# iteration #  80
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.60074667922626, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.10460330555215956
# ###############################
# iteration #  81
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.74711320188403, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.011305057331344398
# ###############################
# iteration #  82
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.64822658565297, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.00591712439939507
# ###############################
# iteration #  83
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.656225197105456, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.006398869480295466
# ###############################
# iteration #  84
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.600835141877134, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.09997313052325864
# ###############################
# iteration #  85
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.740714032861808, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.010962078666158078
# ###############################
# iteration #  86
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.644897638035186, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.007201852720968062
# ###############################
# iteration #  87
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.654656885667892, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.006225936185141963
# ###############################
# iteration #  88
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.600773544193425, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.10042986035208717
# ###############################
# iteration #  89
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.741297661751025, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.01089855394857806
# ###############################
# iteration #  90
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.646030157603851, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.005901762148103576
# ###############################
# iteration #  91
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.654020965569378, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.0014246161428420842
# ###############################
# iteration #  92
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.641692307601334, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.0023939399003647713
# ###############################
# iteration #  93
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.644944014583139, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.006605891529936869
# ###############################
# iteration #  94
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.653895367439794, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.006126783356705005
# ###############################
# iteration #  95
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.600874825331898, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.09727939129208242
# ###############################
# iteration #  96
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.73698087066504, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.010670849152512058
# ###############################
# iteration #  97
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.64374986574579, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.00674891477954784
# ###############################
# iteration #  98
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.652903082321622, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.006005551001675446
# ###############################
# iteration #  99
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.600937631548184, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.09476196865129309

# %%
OD
# Out:
# {('1', '2_p'): 10,
#  ('2', 'R'): 8.600937631548184,
#  ('1', 'R'): 0,
#  ('2_p', 'R'): 0}

# %%
print_final_flows(G_k)
# Out:
# ('1', '2')  :  8.73351553584862
# ('1', 'R')  :  8.623148414995295
# ('1', '2_p')  :  1.2664844641513797
# ('2', '1')  :  8.623148414995295
# ('2', '2_p')  :  8.73351553584862

# %%
print_final_cost(G_k)
# Out:
# ('1', '2')  :  39.14159464788482
# ('1', 'R')  :  41.455995577705075
# ('1', '2_p')  :  90.0
# ('2', '1')  :  38.98577586692724
# ('2', '2_p')  :  52.385119109689185

# %% [markdown]
# ### Analyze output

# %%
attrs=['f_m', 'f_r','cost','k', 'y_m','y_r']
plot_edge_attrs(G_k,y_list,attrs)

# %%
plot_node_attrs(G_k,['ri'])

# %% [markdown]
# # Bi-directionnal problem

# %% [markdown]
# ## Initialize

# %% [markdown]
# ### Parameters

# %%
#parameters
alpha=0.15
beta=4
POTENTIAL_SHIFT=90
INVERSE_DEMAND_SHIFT=80

ZC_EDGE=1

# %%
L_dum=10
#to adapt
#to be read from file if necessary
nodes_list=['1','2','2_p','R','1_p']
edge_list=[('1','2'),('2','1'),('2','2_p'),('1','R'),('1','2_p'),('1','1_p'),('2','1_p'),('2','R')]
k_list=[10,10,3,10,ZC_EDGE,2,ZC_EDGE,10] 
l_list=[10,10,1,L_dum,0,1,0,L_dum]
t_list=[10,10,10,10,ZC_EDGE,10,ZC_EDGE,10]
phi_list=[phi(l_list[i],t_list[i]) for i in range(len(l_list))]
is_negative=[0,0,1,0,0,1,0,0]

nodes_pots=[('2_p',POTENTIAL_SHIFT),('1_p',POTENTIAL_SHIFT)]

# %%
OD=dict()
N=10
OD[('1','2_p')]=N
OD[('2','R')]=N
OD[('2','1_p')]=N
OD[('1','R')]=N

print(OD)
# Out:
# {('1', '2_p'): 10, ('2', 'R'): 10, ('2', '1_p'): 10, ('1', 'R'): 10}

# %% [markdown]
# ### Vizualize and theoretical solution

# %% [markdown]
# #### Axis 1 to 2

# %%
x_12=np.linspace(0,N,100)

C1=BPR(phi_list[0],x_12,k_list[0])
C2=-BPR(phi_list[2],x_12,k_list[2])+INVERSE_DEMAND_SHIFT
KK=C1-C2

# %%
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(x_12,C1,label=("C1"))
plt.plot(x_12,C2,label=("C2"))
plt.xlabel("x_12")
plt.ylabel("Cost")
plt.legend()
plt.grid(True)
plt.subplot(1,2,2)
plt.plot(x_12,KK,label="Total Cost")
plt.plot(x_12,np.ones(x_12.shape)*0,'--')
plt.xlabel("x_12")
plt.ylabel("Cost")
plt.grid(True)

# %% [markdown]
# Plot for illustration

# %%
C_T=BPR_int_val(phi_list[0],x_12,k_list[0])+BPR_int_val(phi_list[2],x_12,k_list[2])-INVERSE_DEMAND_SHIFT*x_12

# %%
plt.figure(figsize=(10,5))
plt.plot(x_12,C_T)
plt.grid(True)
plt.xlabel("x_12")
plt.ylabel("Integral Cost")
# Out:
# Text(0, 0.5, 'Integral Cost')

# %% [markdown]
# Compute the optimum with cvxpy

# %%
x_12=cp.Variable()
constraints=[x_12>=0,x_12<=10]

C_T=BPR_int(phi_list[0],x_12,k_list[0])+BPR_int(phi_list[2],x_12,k_list[2])-INVERSE_DEMAND_SHIFT*x_12
prob=cp.Problem(cp.Minimize(C_T),constraints)
prob.solve()
print(prob.status)
print("optimal flow value:", x_12.value)
# Out:
# optimal_inaccurate
# optimal flow value: 8.649842980893967

# %% [markdown]
# #### Axis 2 to 1

# %%
x_21=np.linspace(0,N,100)

C1=BPR(phi_list[1],x_21,k_list[1])
C2=-BPR(phi_list[5],x_21,k_list[5])+INVERSE_DEMAND_SHIFT
KK=C1-C2

# %%
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(x_21,C1,label=("C1"))
plt.plot(x_21,C2,label=("C2"))
plt.xlabel("x_21")
plt.ylabel("Cost")
plt.ylim([0,100])
plt.legend()
plt.grid(True)
plt.subplot(1,2,2)
plt.plot(x_21,KK,label="Total Cost")
plt.plot(x_21,np.ones(x_21.shape)*0,'--')
plt.xlabel("x_21")
plt.ylabel("Cost")
plt.grid(True)

# %% [markdown]
# Plot for illustration

# %%
C_T=BPR_int_val(phi_list[1],x_21,k_list[1])+BPR_int_val(phi_list[5],x_21,k_list[5])-INVERSE_DEMAND_SHIFT*x_21

# %%
plt.figure(figsize=(10,5))
plt.plot(x_21,C_T)
plt.grid(True)
plt.xlabel("x_12")
plt.ylabel("Integral Cost")
# Out:
# Text(0, 0.5, 'Integral Cost')

# %% [markdown]
# Compute the optimum with cvxpy

# %%
x_21=cp.Variable()
constraints=[x_21>=0,x_21<=10]

C_T=BPR_int(phi_list[1],x_21,k_list[1])+BPR_int(phi_list[5],x_21,k_list[5])-INVERSE_DEMAND_SHIFT*x_21
prob=cp.Problem(cp.Minimize(C_T),constraints)
prob.solve()
print(prob.status)
print("optimal flow value:", x_21.value)
# Out:
# optimal
# optimal flow value: 5.858557487311528

# %% [markdown]
# ### Expected solution

# %%
eq=8.64

plt.figure(figsize=(18,5))
x_21=np.linspace(0,N,100)
x_r=[0,1,2,3,4,5,6,7,8]
for x_ in x_r:
    x_m=np.linspace(0,N,100)
    C1=BPR(phi_list[1],x_m+x_,k_list[1])
    plt.plot(x_m,C1,label=("C1 , x_r: ", x_))
    
C2=-BPR(phi_list[5],x_21,k_list[5])+INVERSE_DEMAND_SHIFT
plt.plot(x_21,C2,label=("C2"))
plt.xlabel("x_m")
plt.ylabel("Cost")
plt.ylim([0,100])
plt.grid(True)
plt.legend()

# %% [markdown]
# ## Run

# %% [markdown]
# ### Init Graph

# %%
OD=dict()
N=10
OD[('1','2_p')]=N
OD[('2','1_p')]=N
# OD[('1','R')]=N
# OD[('2','R')]=N

print(OD)
# Out:
# {('1', '2_p'): 10, ('2', '1_p'): 10}

# %%
G=nx.DiGraph()
G.add_nodes_from(nodes_list)
G.add_edges_from(edge_list)

print(OD)
# Out:
# {('1', '2_p'): 10, ('2', '1_p'): 10}

# %%
G=initEdgeAttr(G,edge_list,k_list,phi_list,is_negative)
G=initNodeAttr(G,nodes_pots)
G=update_costs(G,INVERSE_DEMAND_SHIFT)

#Create a feasible solution for the passengers
G=init_flows(G,OD) 

for e in G.edges():
    print(e," --- ",G.edges[e])

G=update_costs(G,INVERSE_DEMAND_SHIFT)

# #update the ri_k
# ri_k,G=estimate_ri_k(G,dummy_nodes)
# print(ri_k)
#update OD
# OD=update_OD(OD,ri_k,dummy_nodes)
# print(OD)


# #Create a feasible solution for the rebalancers
#but careful with the initialization
# G=init_flows(G,OD,1)



dummy_nodes=dict()
dummy_nodes['2_p']='2'
dummy_nodes['1_p']='1'


print(G.nodes.data())

# for e in G.edges():
#     print(e," --- ",G.edges[e])
# Out:
# ('1', '2')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 10, 'f_r': 0, 'cost': 36.0}
# ('1', 'R')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 0, 'f_r': 0, 'cost': 36.0}
# ('1', '2_p')  ---  {'k': 1, 'phi': 0.0, 'sign': 1, 'f_m': 0, 'f_r': 0, 'cost': 90.0}
# ('1', '1_p')  ---  {'k': 2, 'phi': 3.6, 'sign': -1, 'f_m': 10, 'f_r': 0, 'cost': 13.599999999999994}
# ('2', '1')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 10, 'f_r': 0, 'cost': 36.0}
# ('2', '2_p')  ---  {'k': 3, 'phi': 3.6, 'sign': -1, 'f_m': 10, 'f_r': 0, 'cost': 13.599999999999994}
# ('2', '1_p')  ---  {'k': 1, 'phi': 0.0, 'sign': 1, 'f_m': 0, 'f_r': 0, 'cost': 90.0}
# ('2', 'R')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 0, 'f_r': 0, 'cost': 36.0}
# [('1', {'ri': 0}), ('2', {'ri': 0}), ('2_p', {'pot': 90, 'ri': 0}), ('R', {'ri': 0}), ('1_p', {'pot': 90, 'ri': 0})]

# %%
print(OD)
# Out:
# {('1', '2_p'): 10, ('2', '1_p'): 10}

# %% [markdown]
# ### Run

# %%
G_k,y_list,opt_res,OD=FW(G,OD,edge_list,dummy_nodes,step='line_search')
# Out:
# ###############################
# iteration #  1
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  41.4  ---  80.26666666666668
# Cost for normal edge (1,2,2_p):  121.66666666666669
# Cost for 1-R:  10000000000000000000000
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# optimal
# ###############################
# iteration #  2
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  37.05104207503597  ---  26.575828086863865
# Cost for normal edge (1,2,2_p):  63.62687016189984
# Cost for 1-R:  10000000000000000000000
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# optimal
# ###############################
# iteration #  3
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  37.491540378145544  ---  32.01407874253756
# Cost for normal edge (1,2,2_p):  69.50561912068311
# Cost for 1-R:  36.0
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  4
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  37.8864444755597  ---  36.88943796987286
# Cost for normal edge (1,2,2_p):  74.77588244543256
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  5
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.08610477641753  ---  39.35437995577199
# Cost for normal edge (1,2,2_p):  77.44048473218952
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  6
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.25991679533443  ---  41.50020734980782
# Cost for normal edge (1,2,2_p):  79.76012414514226
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  7
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.36411898970142  ---  42.78665419384468
# Cost for normal edge (1,2,2_p):  81.15077318354611
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  8
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.47116823984773  ---  44.108249874663336
# Cost for normal edge (1,2,2_p):  82.57941811451107
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  9
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.53835585211297  ---  44.9377265692959
# Cost for normal edge (1,2,2_p):  83.47608242140888
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  10
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.611420339360905  ---  45.839757276060496
# Cost for normal edge (1,2,2_p):  84.4511776154214
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  11
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.657853063912114  ---  46.413000789038485
# Cost for normal edge (1,2,2_p):  85.07085385295059
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  12
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.70872016760657  ---  47.04098972353787
# Cost for normal edge (1,2,2_p):  85.74970989114445
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  13
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.743496006529746  ---  47.47032106826849
# Cost for normal edge (1,2,2_p):  86.21381707479824
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  14
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.784535737767676  ---  47.976984416884825
# Cost for normal edge (1,2,2_p):  86.7615201546525
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  15
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.812314137418234  ---  48.3199276224474
# Cost for normal edge (1,2,2_p):  87.13224175986564
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  16
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.84454056700404  ---  48.717784777827646
# Cost for normal edge (1,2,2_p):  87.56232534483169
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  17
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.86561216304834  ---  48.97792793886836
# Cost for normal edge (1,2,2_p):  87.8435401019167
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  18
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.888823198316786  ---  49.26448392983679
# Cost for normal edge (1,2,2_p):  88.15330712815359
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  19
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.9094417831367  ---  49.51903435971237
# Cost for normal edge (1,2,2_p):  88.42847614284906
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  20
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.93152832455115  ---  49.791707710508035
# Cost for normal edge (1,2,2_p):  88.72323603505919
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  21
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.94245738438943  ---  49.92663437517809
# Cost for normal edge (1,2,2_p):  88.86909175956751
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  22
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.956314479245336  ---  50.097709620312834
# Cost for normal edge (1,2,2_p):  89.05402409955818
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  23
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.971082065699  ---  50.280025502456894
# Cost for normal edge (1,2,2_p):  89.2511075681559
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  24
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.98724589413552  ---  50.479578939944666
# Cost for normal edge (1,2,2_p):  89.46682483408019
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  25
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.999214595938675  ---  50.62734069060089
# Cost for normal edge (1,2,2_p):  89.62655528653957
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  26
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.01211244900058  ---  50.78657344445155
# Cost for normal edge (1,2,2_p):  89.79868589345213
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  27
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.0218546068667  ---  50.90684699835429
# Cost for normal edge (1,2,2_p):  89.928701605221
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  28
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.034607288160565  ---  51.0642875081551
# Cost for normal edge (1,2,2_p):  90.09889479631566
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  29
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.019305748695025  ---  50.87537961351883
# Cost for normal edge (1,2,2_p):  89.89468536221386
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  30
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.02609792233898  ---  50.959233609123146
# Cost for normal edge (1,2,2_p):  89.98533153146212
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  31
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.03706345987352  ---  51.094610615722495
# Cost for normal edge (1,2,2_p):  90.13167407559601
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  32
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.95603286359607  ---  50.09423288390218
# Cost for normal edge (1,2,2_p):  89.05026574749826
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  33
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.961871842031464  ---  50.1663190374255
# Cost for normal edge (1,2,2_p):  89.12819087945697
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  34
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.97275006091585  ---  50.300618035998134
# Cost for normal edge (1,2,2_p):  89.27336809691398
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  35
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.98534212209332  ---  50.456075581399084
# Cost for normal edge (1,2,2_p):  89.4414177034924
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  36
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.000652267328086  ---  50.64508972009979
# Cost for normal edge (1,2,2_p):  89.64574198742787
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  37
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.00443700446609  ---  50.691814869951806
# Cost for normal edge (1,2,2_p):  89.6962518744179
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  38
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.009253676837226  ---  50.75127996095336
# Cost for normal edge (1,2,2_p):  89.76053363779059
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  39
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.014330196754685  ---  50.813953046354165
# Cost for normal edge (1,2,2_p):  89.82828324310884
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  40
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.02216009044542  ---  50.91061840056076
# Cost for normal edge (1,2,2_p):  89.93277849100618
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  41
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.03299244778625  ---  51.04435120723763
# Cost for normal edge (1,2,2_p):  90.07734365502388
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  42
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.983406415490336  ---  50.43217796901657
# Cost for normal edge (1,2,2_p):  89.4155843845069
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  43
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.99057746475155  ---  50.52070944137724
# Cost for normal edge (1,2,2_p):  89.51128690612879
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  44
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.00220558652277  ---  50.664266500281094
# Cost for normal edge (1,2,2_p):  89.66647208680386
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  45
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.02161975235384  ---  50.90394755992396
# Cost for normal edge (1,2,2_p):  89.92556731227779
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  46
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.034407213792505  ---  51.06181745422846
# Cost for normal edge (1,2,2_p):  90.09622466802097
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  47
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.98600193014286  ---  50.464221359788425
# Cost for normal edge (1,2,2_p):  89.45022328993129
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  48
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.99442468132103  ---  50.56820594223492
# Cost for normal edge (1,2,2_p):  89.56263062355595
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ###############################
# iteration #  49
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.007075890128014  ---  50.724393705284136
# Cost for normal edge (1,2,2_p):  89.73146959541215
# Cost for 1-R:  41.4
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# optimal_inaccurate

# %%
OD
# Out:
# {('1', '2_p'): 10,
#  ('2', '1_p'): 10,
#  ('1', 'R'): 0,
#  ('2', 'R'): 2.893122072179972,
#  ('2_p', 'R'): 0,
#  ('1_p', 'R'): 0}

# %%
print_final_flows(G_k)
# Out:
# ('1', '2')  :  8.647772676364875
# ('1', 'R')  :  2.893122072179972
# ('1', '2_p')  :  1.3522273236351219
# ('1', '1_p')  :  5.774383157810718
# ('2', '1')  :  8.66750522999069
# ('2', '2_p')  :  8.647772676364875
# ('2', '1_p')  :  4.225616842189282
# ('2', 'R')  :  1.8089371018021216

# %%
print_final_cost(G_k)
# Out:
# ('1', '2')  :  39.007075890128014
# ('1', 'R')  :  41.4
# ('1', '2_p')  :  90.0
# ('1', '1_p')  :  50.37427264570481
# ('2', '1')  :  39.007075890128014
# ('2', '2_p')  :  50.724393705284136
# ('2', '1_p')  :  90.0
# ('2', 'R')  :  10000000000000000000000

# %%
sanity_check_N(G_k)
# Out:
# 1 to 2:  9.999999999999996
# 2 to 1:  10.0

# %%
sanity_check_cost(G_k)
# Out:
# 1 to 2:  90.0  =====  89.73146959541215
# 2 to 1:  90.0  =====  89.38134853583281

# %%
plot_sanity_check_cost(G_k,'log')

# %%
analyze_cost_oscillations(G_k,'1','2','log')

# %% [markdown]
# Interesting: it seems to do the right thing and make really good progress to attaining the objective, but at some stage it becomes erratic and no progress at all is being made.
#
# I am assuming the problem comes from the rebalancers changing relatively often. difficult to go beyond a certain level of accuracy apparently.
#
# To be noted: the oscillations are on both sides of the equilibrium point (i.e. negative and positive). That means you go on both sides of the cost.

# %% [markdown]
# ### Analyze output

# %%
#plot also the theoretical lines (what should the result be, theoretically?)

# %%
attrs=['f_m', 'f_r','cost','k', 'y_m','y_r']
plot_edge_attrs(G_k,y_list,attrs)

# %%
#this is equivalent to plotting the OD pairs at least for the rebalancers
plot_node_attrs(G_k,['ri'])

# %% [markdown]
# The total cost increases logically, as it involves additional flow (rebalancing flow) that was not there in the beginning

# %%
plt.figure(figsize=(10,5))
plt.plot(np.array(opt_res['obj']),'--o')
plt.grid(True)
plt.ylabel("obj value")
plt.xlabel("iteration #")
# Out:
# Text(0.5, 0, 'iteration #')

# %%
plt.figure(figsize=(10,5))
plt.plot(np.array(opt_res['a_k']),'--o')
plt.grid(True)
plt.ylabel("a_k")
plt.xlabel("iteration #")
plt.yscale('log')

# %% [markdown]
# # Understand the oscillations around 0

# %% [markdown]
# # Debug Line Search

# %% [markdown]
# - It started working when removing the node potential from the toal cost. Any explanation? Should we remove it or not?

# %% [markdown]
# # Routines to implement

# %%
# def stopping_criterion(x_k,y_k):

# %% [markdown]
# # Useful nx lines

# %%
nx.get_edge_attributes(G,'f')
# Out:
# {('1', '2'): 0, ('1', 'R'): 0, ('2', '1'): 0, ('2', '2_p'): 0}

# %%
G.nodes.data()
# Out:
# NodeDataView({'1': {}, '2': {}, '2_p': {'pot': 90}, 'R': {}})

# %%
G.edges.data()
# Out:
# OutEdgeDataView([('1', '2', {'k': 1, 'phi': 36.0, 'sign': 1, 'f': 0, 'cost': 36.0}), ('1', 'R', {'k': 10, 'phi': 36.0, 'sign': 1, 'f': 0, 'cost': 36.0}), ('2', '1', {'k': 10, 'phi': 36.0, 'sign': 1, 'f': 0, 'cost': 36.0}), ('2', '2_p', {'k': 10, 'phi': 36.0, 'sign': -1, 'f': 0, 'cost': -36.0})])

# %%
G['1']['2']
# Out:
# {'f': 0, 'k': 1, 'phi': 36.0, 'sign': 1, 'cost': 36.0}
