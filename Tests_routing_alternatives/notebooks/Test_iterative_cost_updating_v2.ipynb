# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Current-Problems" data-toc-modified-id="Current-Problems-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Current Problems</a></span></li><li><span><a href="#Todo:" data-toc-modified-id="Todo:-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Todo:</a></span><ul class="toc-item"><li><span><a href="#Notes" data-toc-modified-id="Notes-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Notes</a></span></li></ul></li><li><span><a href="#Load" data-toc-modified-id="Load-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Load</a></span></li><li><span><a href="#One-directional-problem" data-toc-modified-id="One-directional-problem-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>One directional problem</a></span><ul class="toc-item"><li><span><a href="#Initialize" data-toc-modified-id="Initialize-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Initialize</a></span><ul class="toc-item"><li><span><a href="#Parameters" data-toc-modified-id="Parameters-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Parameters</a></span></li><li><span><a href="#Vizualize-and-theoretical-solution" data-toc-modified-id="Vizualize-and-theoretical-solution-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Vizualize and theoretical solution</a></span></li></ul></li><li><span><a href="#Run" data-toc-modified-id="Run-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Run</a></span><ul class="toc-item"><li><span><a href="#Init-Graph" data-toc-modified-id="Init-Graph-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Init Graph</a></span></li><li><span><a href="#Run" data-toc-modified-id="Run-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Run</a></span></li><li><span><a href="#Analyze-output" data-toc-modified-id="Analyze-output-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Analyze output</a></span></li></ul></li></ul></li><li><span><a href="#Bi-directionnal-problem" data-toc-modified-id="Bi-directionnal-problem-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Bi-directionnal problem</a></span><ul class="toc-item"><li><span><a href="#Initialize" data-toc-modified-id="Initialize-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Initialize</a></span><ul class="toc-item"><li><span><a href="#Parameters" data-toc-modified-id="Parameters-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>Parameters</a></span></li><li><span><a href="#Vizualize-and-theoretical-solution" data-toc-modified-id="Vizualize-and-theoretical-solution-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>Vizualize and theoretical solution</a></span><ul class="toc-item"><li><span><a href="#Axis-1-to-2" data-toc-modified-id="Axis-1-to-2-5.1.2.1"><span class="toc-item-num">5.1.2.1&nbsp;&nbsp;</span>Axis 1 to 2</a></span></li><li><span><a href="#Axis-2-to-1" data-toc-modified-id="Axis-2-to-1-5.1.2.2"><span class="toc-item-num">5.1.2.2&nbsp;&nbsp;</span>Axis 2 to 1</a></span></li></ul></li><li><span><a href="#Expected-solution" data-toc-modified-id="Expected-solution-5.1.3"><span class="toc-item-num">5.1.3&nbsp;&nbsp;</span>Expected solution</a></span></li></ul></li><li><span><a href="#Run" data-toc-modified-id="Run-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Run</a></span><ul class="toc-item"><li><span><a href="#Init-Graph" data-toc-modified-id="Init-Graph-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>Init Graph</a></span></li><li><span><a href="#Run" data-toc-modified-id="Run-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>Run</a></span></li><li><span><a href="#Analyze-output" data-toc-modified-id="Analyze-output-5.2.3"><span class="toc-item-num">5.2.3&nbsp;&nbsp;</span>Analyze output</a></span></li></ul></li></ul></li><li><span><a href="#Understand-the-oscillations-around-0" data-toc-modified-id="Understand-the-oscillations-around-0-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Understand the oscillations around 0</a></span></li><li><span><a href="#LET-US-ANALYZE-THE-SIZE-OF-JUMPS-IN-FLOW-ON-THE-DUMMY-EDGE" data-toc-modified-id="LET-US-ANALYZE-THE-SIZE-OF-JUMPS-IN-FLOW-ON-THE-DUMMY-EDGE-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>LET US ANALYZE THE SIZE OF JUMPS IN FLOW ON THE DUMMY EDGE</a></span><ul class="toc-item"><li><span><a href="#Dummy-edge-1-2p" data-toc-modified-id="Dummy-edge-1-2p-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Dummy edge 1 2p</a></span></li></ul></li><li><span><a href="#Routines-to-implement" data-toc-modified-id="Routines-to-implement-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Routines to implement</a></span></li><li><span><a href="#Useful-nx-lines" data-toc-modified-id="Useful-nx-lines-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Useful nx lines</a></span></li></ul></div>

# %% [markdown]
# # Current Problems

# %% [markdown]
# # Todo:

# %% [markdown]
# - Include good vizualization of the total cost function (from previous MATLAB/Python work) in order to see what the theoretical solution is and to tune your parameters properly (You can use what you have already developed for the previous solution, stored in the vizualization folder)
#
# - Find the good data strcutre to represent the flows over the graph
#
# - Transform Graph into objects, to make it easier to use?
#
# - Stopping criterion for FW
#
# - Introduce node potentials properly (one is the offset for the Demand function, the other one is the potential!

# %% [markdown]
# - Include the vertex potential and the inverse demand shift: two different things!

# %% [markdown]
# ## Notes

# %% [markdown]
# - interesting to note that the algorithm computes the right solution, also for rebalancers, but cannot fulfill it.
# - Actually there is nothing on 1-2p either, which means it does not really work...: THIS IS SOLVED, is was an initialization issue. Makes me confident that the other is also an initialization issue. Which makes sense. At each step, you have to act as if you know all the components (i.e. all the OD pairs)

# %% [markdown]
# - I think it is initialization, it has to be a feasible point.
# - BUT: what is a feasible point when your feasible set evolves over the iterations (essentially, OD pairs in this case)

# %% [markdown]
# - I don't really understand. What does the algorithm do, exactly? It seeks a minimum cost solution that has to respect certain constraints. But here, the constraints are implicit. Therefore, we have to make sure the constraints are always respected, otherwise it will assign zero flow even when there should be flow!! For instance, here, it avoids assigning to 1-R because it does not really need to, you see?

# %% [markdown]
# - Don't forget: the capacities are a mirror for the ri_k
# - think about proper initialization
# - What is the correct way to think about flows? 1. should we split them in m and r? 2. In order to compute the ri_k, I am assuming we should put into it only the flow that goes onto the network (i.e. neglect all the edges that flow directly into dummy node).
# - it seemed like the thing stopped giving the right answer (8.xxx as soon as I introduced a change in the way the ri_k were computed)
# - What is happening is the following: the ALPHA is good at the beginning (first iteration) but then it goes super small for some reason: it does not include the new suggestions.

# %% [markdown]
# # Load

# %%
# %load_ext autoreload
# %autoreload 2
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from routines_icu import *
from helpers_icu import *
import cvxpy as cp
from FW_icu import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # One directional problem

# %% [markdown]
# ## Initialize

# %% [markdown]
# ### Parameters

# %%
#parameters
alpha=0.15
beta=4
POTENTIAL_SHIFT=90
INVERSE_DEMAND_SHIFT=80

ZC_EDGE=1

# %%
#to adapt
#to be read from file if necessary

k_list=[10,10,3,10,ZC_EDGE] 
l_list=[10,10,1,10,0]
t_list=[10,10,10,10,ZC_EDGE]
phi_list=[phi(l_list[i],t_list[i]) for i in range(len(l_list))]
is_negative=[0,0,1,0,0]

nodes_pots=[('2_p',POTENTIAL_SHIFT)]

# %% [markdown]
# ### Vizualize and theoretical solution

# %%
x_12=np.linspace(0,N,100)

C1=BPR(phi_list[0],x_12,k_list[0])
C2=-BPR(phi_list[2],x_12,k_list[2])+INVERSE_DEMAND_SHIFT
KK=C1-C2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f90ebd4ba3c0> in <module>
# ----> 1 x_12=np.linspace(0,N,100)
#       2
#       3 C1=BPR(phi_list[0],x_12,k_list[0])
#       4 C2=-BPR(phi_list[2],x_12,k_list[2])+INVERSE_DEMAND_SHIFT
#       5 KK=C1-C2
#
# NameError: name 'N' is not defined

# %%
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(x_12,C1,label=("C1"))
plt.plot(x_12,C2,label=("C2"))
plt.xlabel("x_12")
plt.ylabel("Cost")
plt.legend()
plt.grid(True)
plt.subplot(1,2,2)
plt.plot(x_12,KK,label="Total Cost")
plt.plot(x_12,np.ones(x_12.shape)*0,'--')
plt.xlabel("x_12")
plt.ylabel("Cost")
plt.grid(True)

# %% [markdown]
# Plot for illustration

# %%
C_T=BPR_int_val(phi_list[0],x_12,k_list[0])+BPR_int_val(phi_list[2],x_12,k_list[2])-INVERSE_DEMAND_SHIFT*x_12

# %%
plt.figure(figsize=(10,5))
plt.plot(x_12,C_T)
plt.grid(True)
plt.xlabel("x_12")
plt.ylabel("Integral Cost")
# Out:
# Text(0, 0.5, 'Integral Cost')

# %% [markdown]
# Compute the optimum with cvxpy

# %%
x_12=cp.Variable()
constraints=[x_12>=0,x_12<=10]

C_T=BPR_int(phi_list[0],x_12,k_list[0])+BPR_int(phi_list[2],x_12,k_list[2])-INVERSE_DEMAND_SHIFT*x_12
prob=cp.Problem(cp.Minimize(C_T),constraints)
prob.solve()
print(prob.status)
print("optimal flow value:", x_12.value)
# Out:
# optimal_inaccurate
# optimal flow value: 8.649843057304913

# %% [markdown]
# ## Run

# %% [markdown]
# ### Init Graph

# %%
G=nx.DiGraph()

nodes_list=['1','2','2_p','R']
edge_list=[('1','2'),('2','1'),('2','2_p'),('1','R'),('1','2_p')]

G.add_nodes_from(nodes_list)
G.add_edges_from(edge_list)

OD=dict()
N=10
OD[('1','2_p')]=N
OD[('2','R')]=N

print(OD)
# Out:
# {('1', '2_p'): 10, ('2', 'R'): 10}

# %%
G=initEdgeAttr(G,edge_list,k_list,phi_list,is_negative)
G=initNodeAttr(G,nodes_pots)
G=update_costs(G,INVERSE_DEMAND_SHIFT)

#Create a feasible solution for the passengers
G=init_flows(G,OD) 

for e in G.edges():
    print(e," --- ",G.edges[e])

G=update_costs(G,INVERSE_DEMAND_SHIFT)

# #update the ri_k
# ri_k,G=estimate_ri_k(G,dummy_nodes)
# print(ri_k)
#update OD
# OD=update_OD(OD,ri_k,dummy_nodes)
# print(OD)


# #Create a feasible solution for the rebalancers
#but careful with the initialization
# G=init_flows(G,OD,1)



dummy_nodes=dict()
dummy_nodes['2_p']='2'


print(G.nodes.data())

for e in G.edges():
    print(e," --- ",G.edges[e])
# Out:
# ('1', '2')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 10, 'f_r': 0, 'cost': 36.0}
# ('1', 'R')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 0, 'f_r': 10, 'cost': 36.0}
# ('1', '2_p')  ---  {'k': 1, 'phi': 0.0, 'sign': 1, 'f_m': 0, 'f_r': 0, 'cost': 90.0}
# ('2', '1')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 0, 'f_r': 10, 'cost': 36.0}
# ('2', '2_p')  ---  {'k': 3, 'phi': 3.6, 'sign': -1, 'f_m': 10, 'f_r': 0, 'cost': 13.599999999999994}
# [('1', {'ri': 0}), ('2', {'ri': 0}), ('2_p', {'pot': 90, 'ri': 0}), ('R', {'ri': 0})]
# ('1', '2')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 10, 'f_r': 0, 'cost': 41.4}
# ('1', 'R')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 0, 'f_r': 10, 'cost': 41.4}
# ('1', '2_p')  ---  {'k': 1, 'phi': 0.0, 'sign': 1, 'f_m': 0, 'f_r': 0, 'cost': 90.0}
# ('2', '1')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 0, 'f_r': 10, 'cost': 41.4}
# ('2', '2_p')  ---  {'k': 3, 'phi': 3.6, 'sign': -1, 'f_m': 10, 'f_r': 0, 'cost': 80.26666666666668}

# %% [markdown]
# ### Run

# %%
G_k,y_list,OD=FW(G,OD,edge_list,dummy_nodes)
# Out:
# ###############################
# iteration #  1
# oD: {('1', '2_p'): 10, ('2', 'R'): 10, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.13672495757101827
# ###############################
# iteration #  2
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.632750424289817, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.99950109954242
# ###############################
# iteration #  3
# oD: {('1', '2_p'): 10, ('2', 'R'): 9.999317878561053, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.09065874593718468
# ###############################
# iteration #  4
# oD: {('1', '2_p'): 10, ('2', 'R'): 9.092792259463438, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.03894358181265262
# ###############################
# iteration #  5
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.73868636020157, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.015291340870998229
# ###############################
# iteration #  6
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.605060128302984, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.3527722397611969
# ###############################
# iteration #  7
# oD: {('1', '2_p'): 10, ('2', 'R'): 9.097156191173736, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.031982944766793475
# ###############################
# iteration #  8
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.806202347176534, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.021605698524377926
# ###############################
# iteration #  9
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.615938194118769, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.25913949269089037
# ###############################
# iteration #  10
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.97460326834767, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.028315814297131252
# ###############################
# iteration #  11
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.72048006881071, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.013027358846178842
# ###############################
# iteration #  12
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.606875245643362, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.2436345767623319
# ###############################
# iteration #  13
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.946288605548169, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.02491175204213299
# ###############################
# iteration #  14
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.723420882109393, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.008776212655867137
# ###############################
# iteration #  15
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.646862285361369, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.1097301519421229
# ###############################
# iteration #  16
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.795342292387282, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.012870521344659248
# ###############################
# iteration #  17
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.682141651679528, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.009257225906605835
# ###############################
# iteration #  18
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.601769105056778, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.22164307068733977
# ###############################
# iteration #  19
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.911677294141901, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.02308802831585362
# ###############################
# iteration #  20
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.705924236433003, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.011836320841472773
# ###############################
# iteration #  21
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.602878123949028, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.19591152340928739
# ###############################
# iteration #  22
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.876590399074615, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.02047786659354185
# ###############################
# iteration #  23
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.694816765076851, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.005781348360331785
# ###############################
# iteration #  24
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.64454900042869, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.06322423537262288
# ###############################
# iteration #  25
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.730246353461643, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.013062463272418712
# ###############################
# iteration #  26
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.616207831110383, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.14237663375475668
# ###############################
# iteration #  27
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.813227501933081, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0
('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.0017875182852990998
# ###############################
# iteration #  77
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.64190156674469, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.005588714062134997
# ###############################
# iteration #  78
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.649491590556387, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.005974811075036565
# ###############################
# iteration #  79
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.65756062315806, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.0065623501127822885
# ###############################
# iteration #  80
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.60074667922626, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.10460330555215956
# ###############################
# iteration #  81
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.74711320188403, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.011305057331344398
# ###############################
# iteration #  82
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.64822658565297, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.00591712439939507
# ###############################
# iteration #  83
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.656225197105456, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.006398869480295466
# ###############################
# iteration #  84
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.600835141877134, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.09997313052325864
# ###############################
# iteration #  85
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.740714032861808, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.010962078666158078
# ###############################
# iteration #  86
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.644897638035186, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.007201852720968062
# ###############################
# iteration #  87
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.654656885667892, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.006225936185141963
# ###############################
# iteration #  88
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.600773544193425, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.10042986035208717
# ###############################
# iteration #  89
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.741297661751025, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.01089855394857806
# ###############################
# iteration #  90
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.646030157603851, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.005901762148103576
# ###############################
# iteration #  91
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.654020965569378, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.0014246161428420842
# ###############################
# iteration #  92
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.641692307601334, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.0023939399003647713
# ###############################
# iteration #  93
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.644944014583139, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.006605891529936869
# ###############################
# iteration #  94
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.653895367439794, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.006126783356705005
# ###############################
# iteration #  95
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.600874825331898, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.09727939129208242
# ###############################
# iteration #  96
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.73698087066504, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.010670849152512058
# ###############################
# iteration #  97
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.64374986574579, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.00674891477954784
# ###############################
# iteration #  98
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.652903082321622, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.006005551001675446
# ###############################
# iteration #  99
# oD: {('1', '2_p'): 10, ('2', 'R'): 8.600937631548184, ('1', 'R'): 0, ('2_p', 'R'): 0}
# AON, (o,d): 1 2_p
# AON, (o,d): 2 R
# optimal_inaccurate
# ALPHA: 0.09476196865129309

# %%
OD
# Out:
# {('1', '2_p'): 10,
#  ('2', 'R'): 8.600937631548184,
#  ('1', 'R'): 0,
#  ('2_p', 'R'): 0}

# %%
print_final_flows(G_k)
# Out:
# ('1', '2')  :  8.73351553584862
# ('1', 'R')  :  8.623148414995295
# ('1', '2_p')  :  1.2664844641513797
# ('2', '1')  :  8.623148414995295
# ('2', '2_p')  :  8.73351553584862

# %%
print_final_cost(G_k)
# Out:
# ('1', '2')  :  39.14159464788482
# ('1', 'R')  :  41.455995577705075
# ('1', '2_p')  :  90.0
# ('2', '1')  :  38.98577586692724
# ('2', '2_p')  :  52.385119109689185

# %% [markdown]
# ### Analyze output

# %%
attrs=['f_m', 'f_r','cost','k', 'y_m','y_r']
plot_edge_attrs(G_k,y_list,attrs)

# %%
plot_node_attrs(G_k,['ri'])

# %% [markdown]
# # Bi-directionnal problem

# %% [markdown]
# ## Initialize

# %% [markdown]
# ### Parameters

# %%
#parameters
alpha=0.15
beta=4
POTENTIAL_SHIFT=90
INVERSE_DEMAND_SHIFT=80

ZC_EDGE=1

# %%
L_dum=10
#to adapt
#to be read from file if necessary
nodes_list=['1','2','2_p','R','1_p']
edge_list=[('1','2'),('2','1'),('2','2_p'),('1','R'),('1','2_p'),('1','1_p'),('2','1_p'),('2','R')]
k_list=[10,10,3,10,ZC_EDGE,2,ZC_EDGE,10] 
l_list=[10,10,1,L_dum,0,1,0,L_dum]
t_list=[10,10,10,10,ZC_EDGE,10,ZC_EDGE,10]
phi_list=[phi(l_list[i],t_list[i]) for i in range(len(l_list))]
is_negative=[0,0,1,0,0,1,0,0]

nodes_pots=[('2_p',POTENTIAL_SHIFT),('1_p',POTENTIAL_SHIFT)]

# %%
OD=dict()
N=10
OD[('1','2_p')]=N
OD[('2','R')]=N
OD[('2','1_p')]=N
OD[('1','R')]=N

print(OD)
# Out:
# {('1', '2_p'): 10, ('2', 'R'): 10, ('2', '1_p'): 10, ('1', 'R'): 10}

# %% [markdown]
# ### Vizualize and theoretical solution

# %% [markdown]
# #### Axis 1 to 2

# %%
x_12=np.linspace(0,N,100)

C1=BPR(phi_list[0],x_12,k_list[0])
C2=-BPR(phi_list[2],x_12,k_list[2])+INVERSE_DEMAND_SHIFT
KK=C1-C2

# %%
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(x_12,C1,label=("C1"))
plt.plot(x_12,C2,label=("C2"))
plt.xlabel("x_12")
plt.ylabel("Cost")
plt.legend()
plt.grid(True)
plt.subplot(1,2,2)
plt.plot(x_12,KK,label="Total Cost")
plt.plot(x_12,np.ones(x_12.shape)*0,'--')
plt.xlabel("x_12")
plt.ylabel("Cost")
plt.grid(True)

# %% [markdown]
# Plot for illustration

# %%
C_T=BPR_int_val(phi_list[0],x_12,k_list[0])+BPR_int_val(phi_list[2],x_12,k_list[2])-INVERSE_DEMAND_SHIFT*x_12

# %%
plt.figure(figsize=(10,5))
plt.plot(x_12,C_T)
plt.grid(True)
plt.xlabel("x_12")
plt.ylabel("Integral Cost")
# Out:
# Text(0, 0.5, 'Integral Cost')

# %% [markdown]
# Compute the optimum with cvxpy

# %%
x_12=cp.Variable()
constraints=[x_12>=0,x_12<=10]

C_T=BPR_int(phi_list[0],x_12,k_list[0])+BPR_int(phi_list[2],x_12,k_list[2])-INVERSE_DEMAND_SHIFT*x_12
prob=cp.Problem(cp.Minimize(C_T),constraints)
prob.solve()
print(prob.status)
print("optimal flow value:", x_12.value)
# Out:
# optimal_inaccurate
# optimal flow value: 8.649842980893967

# %% [markdown]
# #### Axis 2 to 1

# %%
x_21=np.linspace(0,N,100)

C1=BPR(phi_list[1],x_21,k_list[1])
C2=-BPR(phi_list[5],x_21,k_list[5])+INVERSE_DEMAND_SHIFT
KK=C1-C2

# %%
plt.figure(figsize=(13,5))
plt.subplot(1,2,1)
plt.plot(x_21,C1,label=("C1"))
plt.plot(x_21,C2,label=("C2"))
plt.xlabel("x_21")
plt.ylabel("Cost")
plt.ylim([0,100])
plt.legend()
plt.grid(True)
plt.subplot(1,2,2)
plt.plot(x_21,KK,label="Total Cost")
plt.plot(x_21,np.ones(x_21.shape)*0,'--')
plt.xlabel("x_21")
plt.ylabel("Cost")
plt.grid(True)

# %% [markdown]
# Plot for illustration

# %%
C_T=BPR_int_val(phi_list[1],x_21,k_list[1])+BPR_int_val(phi_list[5],x_21,k_list[5])-INVERSE_DEMAND_SHIFT*x_21

# %%
plt.figure(figsize=(10,5))
plt.plot(x_21,C_T)
plt.grid(True)
plt.xlabel("x_12")
plt.ylabel("Integral Cost")
# Out:
# Text(0, 0.5, 'Integral Cost')

# %% [markdown]
# Compute the optimum with cvxpy

# %%
x_21=cp.Variable()
constraints=[x_21>=0,x_21<=10]

C_T=BPR_int(phi_list[1],x_21,k_list[1])+BPR_int(phi_list[5],x_21,k_list[5])-INVERSE_DEMAND_SHIFT*x_21
prob=cp.Problem(cp.Minimize(C_T),constraints)
prob.solve()
print(prob.status)
print("optimal flow value:", x_21.value)
# Out:
# optimal
# optimal flow value: 5.858557487311528

# %% [markdown]
# ### Expected solution

# %%
eq=8.64

plt.figure(figsize=(18,5))
x_21=np.linspace(0,N,100)
x_r=[0,1,2,3,4,5,6,7,8]
for x_ in x_r:
    x_m=np.linspace(0,N,100)
    C1=BPR(phi_list[1],x_m+x_,k_list[1])
    plt.plot(x_m,C1,label=("C1 , x_r: ", x_))
    
C2=-BPR(phi_list[5],x_21,k_list[5])+INVERSE_DEMAND_SHIFT
plt.plot(x_21,C2,label=("C2"))
plt.xlabel("x_m")
plt.ylabel("Cost")
plt.ylim([0,100])
plt.grid(True)
plt.legend()

# %% [markdown]
# ## Run

# %% [markdown]
# ### Init Graph

# %%
OD=dict()
N=10
OD[('1','2_p')]=N
OD[('2','1_p')]=N
# OD[('1','R')]=N
# OD[('2','R')]=N

print(OD)
# Out:
# {('1', '2_p'): 10, ('2', '1_p'): 10}

# %%
G=nx.DiGraph()
G.add_nodes_from(nodes_list)
G.add_edges_from(edge_list)

print(OD)
# Out:
# {('1', '2_p'): 10, ('2', '1_p'): 10}

# %%
G=initEdgeAttr(G,edge_list,k_list,phi_list,is_negative)
G=initNodeAttr(G,nodes_pots)
G=update_costs(G,INVERSE_DEMAND_SHIFT)

#Create a feasible solution for the passengers
G=init_flows(G,OD) 

for e in G.edges():
    print(e," --- ",G.edges[e])

G=update_costs(G,INVERSE_DEMAND_SHIFT)

# #update the ri_k
# ri_k,G=estimate_ri_k(G,dummy_nodes)
# print(ri_k)
#update OD
# OD=update_OD(OD,ri_k,dummy_nodes)
# print(OD)


# #Create a feasible solution for the rebalancers
#but careful with the initialization
# G=init_flows(G,OD,1)



dummy_nodes=dict()
dummy_nodes['2_p']='2'
dummy_nodes['1_p']='1'


print(G.nodes.data())

# for e in G.edges():
#     print(e," --- ",G.edges[e])
# Out:
# ('1', '2')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 10, 'f_r': 0, 'cost': 36.0}
# ('1', 'R')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 0, 'f_r': 0, 'cost': 36.0}
# ('1', '2_p')  ---  {'k': 1, 'phi': 0.0, 'sign': 1, 'f_m': 0, 'f_r': 0, 'cost': 90.0}
# ('1', '1_p')  ---  {'k': 2, 'phi': 3.6, 'sign': -1, 'f_m': 10, 'f_r': 0, 'cost': 13.599999999999994}
# ('2', '1')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 10, 'f_r': 0, 'cost': 36.0}
# ('2', '2_p')  ---  {'k': 3, 'phi': 3.6, 'sign': -1, 'f_m': 10, 'f_r': 0, 'cost': 13.599999999999994}
# ('2', '1_p')  ---  {'k': 1, 'phi': 0.0, 'sign': 1, 'f_m': 0, 'f_r': 0, 'cost': 90.0}
# ('2', 'R')  ---  {'k': 10, 'phi': 36.0, 'sign': 1, 'f_m': 0, 'f_r': 0, 'cost': 36.0}
# [('1', {'ri': 0}), ('2', {'ri': 0}), ('2_p', {'pot': 90, 'ri': 0}), ('R', {'ri': 0}), ('1_p', {'pot': 90, 'ri': 0})]

# %% [markdown]
# ### Run

# %%
G_k,y_list,opt_res,OD=FW(G,OD,edge_list,dummy_nodes,maxIter=2000,
                         step='fixed', rebalancer_smoothing=True, ri_smoothing=True)
# Out:
# ###############################
# iteration #  1
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  41.4  ---  80.26666666666668
# Cost for normal edge (1,2,2_p):  121.66666666666669
# Cost for 1-R:  10000000000000000000000
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# ###############################
# iteration #  2
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  36.000823045267495  ---  13.610161052685058
# Cost for normal edge (1,2,2_p):  49.61098409795255
# Cost for 1-R:  10000000000000000000000
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# ###############################
# iteration #  3
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  37.9761316872428  ---  37.99668749682467
# Cost for normal edge (1,2,2_p):  75.97281918406748
# Cost for 1-R:  10000000000000000000000
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# ###############################
# iteration #  4
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.868521984  ---  61.35953066666666
# Cost for normal edge (1,2,2_p):  101.22805265066665
# Cost for 1-R:  36.0
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  5
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  36.15094370186008  ---  15.463502492099778
# Cost for normal edge (1,2,2_p):  51.61444619395986
# Cost for 1-R:  10000000000000000000000
# Cost for 2-R:  40.293034251587905
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 1 R
# ###############################
# iteration #  6
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  37.284819939565644  ---  29.461974562538856
# Cost for normal edge (1,2,2_p):  66.7467945021045
# Cost for 1-R:  36.02360073746041
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  7
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.567163110087186  ---  45.293371729471446
# Cost for normal edge (1,2,2_p):  83.86053483955862
# Cost for 1-R:  36.66695719452988
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  8
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.50181027424699  ---  56.832225607987546
# Cost for normal edge (1,2,2_p):  96.33403588223453
# Cost for 1-R:  36.137337854662235
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  9
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  36.58750627362061  ---  20.853163871859394
# Cost for normal edge (1,2,2_p):  57.440670145480006
# Cost for 1-R:  10000000000000000000000
# Cost for 2-R:  39607.28189513326
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 1 R
# ###############################
# iteration #  10
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  37.41162168615915  ---  31.027428224187005
# Cost for normal edge (1,2,2_p):  68.43904991034616
# Cost for 1-R:  36.49413385323243
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  11
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.235290014689475  ---  41.19617302085779
# Cost for normal edge (1,2,2_p):  79.43146303554727
# Cost for 1-R:  38.52182843129701
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  12
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.930788024148825  ---  49.78256819936824
# Cost for normal edge (1,2,2_p):  88.71335622351707
# Cost for 1-R:  36.3310164581164
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  13
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.47891730523537  ---  56.54959636093058
# Cost for normal edge (1,2,2_p):  96.02851366616595
# Cost for 1-R:  37.478537058981104
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  14
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  37.10728865836755  ---  27.270230350216714
# Cost for normal edge (1,2,2_p):  64.37751900858427
# Cost for 1-R:  10000000000000000000000
# Cost for 2-R:  14859906.120086426
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 1 R
# ###############################
# iteration #  15
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  37.70480003789079  ---  34.646914048034425
# Cost for normal edge (1,2,2_p):  72.35171408592521
# Cost for 1-R:  39.32218974623823
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  16
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.26809522290963  ---  41.601175591476874
# Cost for normal edge (1,2,2_p):  79.86927081438651
# Cost for 1-R:  44.538759714135814
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  17
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.76558023773736  ---  47.74296589799211
# Cost for normal edge (1,2,2_p):  86.50854613572946
# Cost for 1-R:  36.7862837914578
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  18
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.18976114692122  ---  52.97976724594104
# Cost for normal edge (1,2,2_p):  92.16952839286226
# Cost for 1-R:  38.164271571274526
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  19
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  37.373087581481585  ---  30.551698536809624
# Cost for normal edge (1,2,2_p):  67.92478611829121
# Cost for 1-R:  41.06406108473266
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  20
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  37.827280122996164  ---  36.159013864150154
# Cost for normal edge (1,2,2_p):  73.98629398714633
# Cost for 1-R:  46.572526655769465
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  21
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.25509637702566  ---  41.44069601266242
# Cost for normal edge (1,2,2_p):  79.69579238968808
# Cost for 1-R:  56.279989443107
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  22
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.64406932892236  ---  46.242831221263756
# Cost for normal edge (1,2,2_p):  84.88690055018611
# Cost for 1-R:  37.715320720716065
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  23
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.990015288118755  ---  50.51376898912047
# Cost for normal edge (1,2,2_p):  89.50378427723922
# Cost for 1-R:  39.5796018653766
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  24
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.293493902261176  ---  54.2604185464343
# Cost for normal edge (1,2,2_p):  93.55391244869548
# Cost for 1-R:  36.939991722112964
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  25
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  37.736041143729246  ---  35.03260671270671
# Cost for normal edge (1,2,2_p):  72.76864785643596
# Cost for 1-R:  57.812672861709075
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  26
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.08454144037353  ---  39.335079510784254
# Cost for normal edge (1,2,2_p):  77.41962095115778
# Cost for 1-R:  38.53997695152426
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  27
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.41069069382117  ---  43.36161350396509
# Cost for normal edge (1,2,2_p):  81.77230419778626
# Cost for 1-R:  40.6495217646267
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  28
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.71061212620459  ---  47.06434723709371
# Cost for normal edge (1,2,2_p):  85.77495936329831
# Cost for 1-R:  44.01021113442613
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  29
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.98310330539585  ---  50.428435869084524
# Cost for normal edge (1,2,2_p):  89.41153917448037
# Cost for 1-R:  37.80625462991899
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  30
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.228631003576105  ---  53.45964201945814
# Cost for normal edge (1,2,2_p):  92.68827302303424
# Cost for 1-R:  39.20111288073482
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  31
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  37.92658699365555  ---  37.38502461303148
# Cost for normal edge (1,2,2_p):  75.31161160668702
# Cost for 1-R:  41.36673130879915
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  32
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.20691717191714  ---  40.84589101132276
# Cost for normal edge (1,2,2_p):  79.0528081832399
# Cost for 1-R:  44.60306669355735
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  33
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.47067962860482  ---  44.10221763709657
# Cost for normal edge (1,2,2_p):  82.57289726570139
# Cost for 1-R:  38.2203496438565
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  34
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.71620365469836  ---  47.1333784530662
# Cost for normal edge (1,2,2_p):  85.84958210776456
# Cost for 1-R:  39.64548272446394
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  35
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.94295533145059  ---  49.93278186976033
# Cost for normal edge (1,2,2_p):  88.87573720121092
# Cost for 1-R:  41.73855674595646
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  36
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.151164743002205  ---  52.50326843212594
# Cost for normal edge (1,2,2_p):  91.65443317512815
# Cost for 1-R:  37.93574207070276
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  37
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.77936468541651  ---  47.91314426440132
# Cost for normal edge (1,2,2_p):  86.69250894981784
# Cost for 1-R:  39.085302748813504
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  60
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.911165289468  ---  49.54031221565431
# Cost for normal edge (1,2,2_p):  88.45147750512231
# Cost for 1-R:  40.06859583054344
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  61
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.03660247690273  ---  51.08891946793496
# Cost for normal edge (1,2,2_p):  90.12552194483769
# Cost for 1-R:  38.27126754365473
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  62
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.34586073659193  ---  42.5612436616287
# Cost for normal edge (1,2,2_p):  80.90710439822064
# Cost for 1-R:  43.35722416279413
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  63
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.48253959751026  ---  44.24863700629952
# Cost for normal edge (1,2,2_p):  82.73117660380979
# Cost for 1-R:  45.329854247867075
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  64
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.61409863141561  ---  45.87282261006924
# Cost for normal edge (1,2,2_p):  84.48692124148485
# Cost for 1-R:  40.397727219404544
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  65
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.74043727917201  ---  47.432559002123625
# Cost for normal edge (1,2,2_p):  86.17299628129564
# Cost for 1-R:  41.618299293386556
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  66
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.86152480300002  ---  48.92746670370397
# Cost for normal edge (1,2,2_p):  87.788991506704
# Cost for 1-R:  39.042364963449664
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  67
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.97738650953629  ---  50.357858142423275
# Cost for normal edge (1,2,2_p):  89.33524465195956
# Cost for 1-R:  39.9029047038347
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  68
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.088092055075016  ---  51.72459327253107
# Cost for normal edge (1,2,2_p):  90.81268532760609
# Cost for 1-R:  38.331529822525376
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  69
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.44893478239049  ---  43.83376274556159
# Cost for normal edge (1,2,2_p):  82.28269752795208
# Cost for 1-R:  42.617795020204575
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  70
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.57004770344486  ---  45.328983993146466
# Cost for normal edge (1,2,2_p):  83.89903169659132
# Cost for 1-R:  44.22188000703733
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  71
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.68685721969833  ---  46.771076786399135
# Cost for normal edge (1,2,2_p):  85.45793400609747
# Cost for 1-R:  40.289492276986635
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  72
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.79932149522941  ---  48.159524632461796
# Cost for normal edge (1,2,2_p):  86.9588461276912
# Cost for 1-R:  41.358178669729995
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  73
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.90744096810864  ---  49.494332939612825
# Cost for normal edge (1,2,2_p):  88.40177390772146
# Cost for 1-R:  39.10959481782818
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  74
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.01125045606388  ---  50.7759315563442
# Cost for normal edge (1,2,2_p):  89.78718201240807
# Cost for 1-R:  39.89638285350793
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  75
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.110812382620594  ---  52.005091143464185
# Cost for normal edge (1,2,2_p):  91.11590352608478
# Cost for 1-R:  38.445688986967426
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  76
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.520218090978865  ---  44.71380359233166
# Cost for normal edge (1,2,2_p):  83.23402168331052
# Cost for 1-R:  42.26547764973384
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  77
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.62904248786619  ---  46.057314665014694
# Cost for normal edge (1,2,2_p):  84.68635715288087
# Cost for 1-R:  43.64540316368611
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  78
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.73423211391455  ---  47.35595202363638
# Cost for normal edge (1,2,2_p):  86.09018413755092
# Cost for 1-R:  40.2943815273529
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  79
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.83577064673051  ---  48.60951415716677
# Cost for normal edge (1,2,2_p):  87.44528480389728
# Cost for 1-R:  41.26202475096891
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  80
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.93366910195081  ---  49.818137061121114
# Cost for normal edge (1,2,2_p):  88.75180616307193
# Cost for 1-R:  39.21836819330845
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  81
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.02796102138615  ---  50.98223483192774
# Cost for normal edge (1,2,2_p):  90.01019585331389
# Cost for 1-R:  39.95322717866287
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  82
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.4911833480668  ---  44.355349976133276
# Cost for normal edge (1,2,2_p):  82.84653332420007
# Cost for 1-R:  40.818762732938815
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  83
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.59274620585683  ---  45.609212417985574
# Cost for normal edge (1,2,2_p):  84.2019586238424
# Cost for 1-R:  41.832449384748614
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  84
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.691215537081504  ---  46.824883173845784
# Cost for normal edge (1,2,2_p):  85.51609871092728
# Cost for 1-R:  43.01344353919783
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  85
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.786569357673756  ---  48.002090835478484
# Cost for normal edge (1,2,2_p):  86.78866019315224
# Cost for 1-R:  40.191677619122416
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  86
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.87880720370134  ---  49.14082967532524
# Cost for normal edge (1,2,2_p):  88.01963687902659
# Cost for 1-R:  41.05670212367447
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  87
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.96794668143757  ---  50.24131705478478
# Cost for normal edge (1,2,2_p):  89.20926373622234
# Cost for 1-R:  39.23797345450807
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  88
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.05402043512775  ---  51.3039559892315
# Cost for normal edge (1,2,2_p):  90.35797642435924
# Cost for 1-R:  39.91371596378844
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  89
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.55148629772183  ---  45.09983083607198
# Cost for normal edge (1,2,2_p):  83.65131713379381
# Cost for 1-R:  45.25077784000715
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  90
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.64418699902099  ---  46.244283938530685
# Cost for normal edge (1,2,2_p):  84.88847093755167
# Cost for 1-R:  41.413891114898604
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  91
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.73420888091534  ---  47.35566519648565
# Cost for normal edge (1,2,2_p):  86.08987407740099
# Cost for 1-R:  42.430192517727264
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  92
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.821543080908825  ---  48.43386519640525
# Cost for normal edge (1,2,2_p):  87.25540827731407
# Cost for 1-R:  40.04763070726023
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  93
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.90619552982216  ---  49.47895715829834
# Cost for normal edge (1,2,2_p):  88.38515268812051
# Cost for 1-R:  40.81959327549374
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  94
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.9881846948742  ---  50.49116907252103
# Cost for normal edge (1,2,2_p):  89.47935376739522
# Cost for 1-R:  39.21057324959528
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  95
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.06753958116047  ---  51.47085902667245
# Cost for normal edge (1,2,2_p):  90.53839860783292
# Cost for 1-R:  39.82869597664908
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  96
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.5966005420318  ---  45.65679681520743
# Cost for normal edge (1,2,2_p):  84.25339735723924
# Cost for 1-R:  44.41758250138699
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  97
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.68192032061761  ---  46.71012741503215
# Cost for normal edge (1,2,2_p):  85.39204773564975
# Cost for 1-R:  41.195337418013985
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  98
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.7649058486147  ---  47.73464010635434
# Cost for normal edge (1,2,2_p):  86.49954595496905
# Cost for 1-R:  42.1016104772261
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  99
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.84555478121325  ---  48.73030594090435
# Cost for normal edge (1,2,2_p):  87.5758607221176
# Cost for 1-R:  39.99904305689245
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  100
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.92387533602193  ---  49.69722637064104
# Cost for normal edge (1,2,2_p):  88.62110170666297
# Cost for 1-R:  40.706232699558996
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  101
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.99988476142765  ---  50.635614338612946
# Cost for normal edge (1,2,2_p):  89.63549910004059
# Cost for 1-R:  39.23518642297321
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  102
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.073607970670125  ---  51.54577741568055
# Cost for normal edge (1,2,2_p):  90.61938538635067
# Cost for 1-R:  39.8120442688728
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  103
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  125
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.76451270857013  ---  47.72978652555719
# Cost for normal edge (1,2,2_p):  86.49429923412731
# Cost for 1-R:  41.00160858172935
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  126
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.82801300638474  ---  48.513740819564674
# Cost for normal edge (1,2,2_p):  87.34175382594941
# Cost for 1-R:  41.674363446132716
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  127
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.89007737622215  ---  49.279967607680874
# Cost for normal edge (1,2,2_p):  88.17004498390303
# Cost for 1-R:  40.123421130624386
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  128
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.95071283474531  ---  50.02855351537417
# Cost for normal edge (1,2,2_p):  88.97926635011947
# Cost for 1-R:  40.68314445363824
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  129
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.0099295207661  ---  50.75962371316179
# Cost for normal edge (1,2,2_p):  89.7695532339279
# Cost for 1-R:  41.303075422458825
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  130
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.067740310078825  ---  51.47333716146707
# Cost for normal edge (1,2,2_p):  90.54107747154589
# Cost for 1-R:  39.91400428953539
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  131
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.71502580564445  ---  47.11883710672161
# Cost for normal edge (1,2,2_p):  85.83386291236606
# Cost for 1-R:  42.86032953045524
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  132
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.776337919831484  ---  47.87577678804298
# Cost for normal edge (1,2,2_p):  86.65211470787446
# Cost for 1-R:  40.93365288223598
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  133
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.8363551973912  ---  48.616730831990125
# Cost for normal edge (1,2,2_p):  87.45308602938132
# Cost for 1-R:  41.56188351317496
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  134
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.895081112572655  ---  49.34174213052663
# Cost for normal edge (1,2,2_p):  88.23682324309928
# Cost for 1-R:  40.118422702704756
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  135
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.952521961164315  ---  50.050888409436034
# Cost for normal edge (1,2,2_p):  89.00341037060035
# Cost for 1-R:  40.647246184682906
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  136
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.00868653954686  ---  50.74427826601053
# Cost for normal edge (1,2,2_p):  89.75296480555738
# Cost for 1-R:  41.229940980270804
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  137
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.06358585047714  ---  51.422047536754846
# Cost for normal edge (1,2,2_p):  90.48563338723199
# Cost for 1-R:  39.926061496541536
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  138
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.72819990983785  ---  47.281480368368506
# Cost for normal edge (1,2,2_p):  86.00968027820636
# Cost for 1-R:  42.67586635425112
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  139
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.78627511668462  ---  47.998458230674366
# Cost for normal edge (1,2,2_p):  86.78473334735898
# Cost for 1-R:  40.896073404923726
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  140
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.843179588156744  ---  48.70098256983639
# Cost for normal edge (1,2,2_p):  87.54416215799313
# Cost for 1-R:  41.487595271492424
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  141
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.89891667209173  ---  49.38909471718189
# Cost for normal edge (1,2,2_p):  88.28801138927362
# Cost for 1-R:  40.130519077677
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  142
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.953491992401396  ---  50.0628641037209
# Cost for normal edge (1,2,2_p):  89.0163560961223
# Cost for 1-R:  40.633420638921166
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  143
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.00691320139125  ---  50.7223852023611
# Cost for normal edge (1,2,2_p):  89.72929840375235
# Cost for 1-R:  41.18495238868918
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  144
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.059189751768315  ---  51.36777471318909
# Cost for normal edge (1,2,2_p):  90.42696446495741
# Cost for 1-R:  39.950646469708296
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  145
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.73957696690408  ---  47.421937863013326
# Cost for normal edge (1,2,2_p):  86.16151482991741
# Cost for 1-R:  42.53858679671002
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  146
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  38.79474478614068  ---  48.10302205111948
# Cost for normal edge (1,2,2_p):  86.89776683726016
# ...
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.01192150029337  ---  50.78421605300454
# Cost for normal edge (1,2,2_p):  89.79613755329791
# Cost for 1-R:  41.31461008289234
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1975
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.01575382814204  ---  50.83152874249426
# Cost for normal edge (1,2,2_p):  89.8472825706363
# Cost for 1-R:  41.35788257463783
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1976
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.019580110748635  ---  50.87876679936582
# Cost for normal edge (1,2,2_p):  89.89834691011445
# Cost for 1-R:  41.40144090105348
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1977
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.023400352196845  ---  50.92593027403511
# Cost for normal edge (1,2,2_p):  89.94933062623195
# Cost for 1-R:  41.29448000594639
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1978
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.027214556613444  ---  50.973019217449945
# Cost for normal edge (1,2,2_p):  90.00023377406339
# Cost for 1-R:  41.337543534468985
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1979
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.00283852528895  ---  50.67208055912282
# Cost for normal edge (1,2,2_p):  89.67491908441177
# Cost for 1-R:  41.380891209987034
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1980
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.0066708605562  ---  50.71939334020001
# Cost for normal edge (1,2,2_p):  89.72606420075621
# Cost for 1-R:  41.42452449480291
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1981
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.01049718605106  ---  50.76663192655639
# Cost for normal edge (1,2,2_p):  89.77712911260745
# Cost for 1-R:  41.3171400053039
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1982
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.0143175057093  ---  50.81379636678152
# Cost for normal edge (1,2,2_p):  89.82811387249082
# Cost for 1-R:  41.36027715279685
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1983
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.01813182351004  ---  50.86088671000049
# Cost for normal edge (1,2,2_p):  89.87901853351053
# Cost for 1-R:  41.403698217287875
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1984
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.021940143475405  ---  50.90790300586922
# Cost for normal edge (1,2,2_p):  89.92984314934463
# Cost for 1-R:  41.29704902083582
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1985
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.02574246967013  ---  50.95484530456954
# Cost for normal edge (1,2,2_p):  89.98058777423967
# Cost for 1-R:  41.33997843357125
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1986
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.02953880620114  ---  51.00171365680423
# Cost for normal edge (1,2,2_p):  90.03125246300536
# Cost for 1-R:  41.23518737695585
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1987
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.005241881833896  ---  50.70175162757897
# Cost for normal edge (1,2,2_p):  89.70699350941287
# Cost for 1-R:  41.42706783522946
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1988
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.00905625707336  ---  50.74884267991798
# Cost for normal edge (1,2,2_p):  89.75789893699134
# Cost for 1-R:  41.470851030973996
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1989
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.01286466947643  ---  50.79586011699299
# Cost for normal edge (1,2,2_p):  89.80872478646941
# Cost for 1-R:  41.36261747227296
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1990
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.01666712296194  ---  50.8428039871845
# Cost for normal edge (1,2,2_p):  89.85947111014644
# Cost for 1-R:  41.40590185962063
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1991
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.0204636214912  ---  50.88967433939762
# Cost for normal edge (1,2,2_p):  89.91013796088882
# Cost for 1-R:  41.29956354393627
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1992
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.02425416906767  ---  50.93647122305763
# Cost for normal edge (1,2,2_p):  89.9607253921253
# Cost for 1-R:  41.34235940063627
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1993
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.02803876973649  ---  50.98319468810484
# Cost for normal edge (1,2,2_p):  90.01123345784133
# Cost for 1-R:  41.23786783169738
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1994
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.00383878699343  ---  50.68442946905457
# Cost for normal edge (1,2,2_p):  89.68826825604799
# Cost for 1-R:  41.42917351158161
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1995
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.00764126727917  ---  50.73137367011316
# Cost for normal edge (1,2,2_p):  89.73901493739233
# Cost for 1-R:  41.472817427991195
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1996
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.01143782726628  ---  50.77824478106519
# Cost for normal edge (1,2,2_p):  89.78968260833147
# Cost for 1-R:  41.364905658791464
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1997
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.01522847081455  ---  50.825042849562294
# Cost for normal edge (1,2,2_p):  89.84027132037684
# Cost for 1-R:  41.40805396261391
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1998
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.01901320182574  ---  50.87176792377469
# Cost for normal edge (1,2,2_p):  89.89078112560043
# Cost for 1-R:  41.302025666853496
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R
# ###############################
# iteration #  1999
# Cost for dummy edge:  90.0
# Cost for normal edge (1,2),(2,2_p):  39.02279202424334  ---  50.91842005238689
# Cost for normal edge (1,2,2_p):  89.94121207663022
# Cost for 1-R:  41.34468853614555
# Cost for 2-R:  10000000000000000000000
# AON, (o,d): 1 2_p
# AON, (o,d): 2 1_p
# AON, (o,d): 2 R

# %%
OD
# Out:
# {('1', '2_p'): 10,
#  ('2', '1_p'): 10,
#  ('1', 'R'): 0,
#  ('2', 'R'): 2.8791747067405735,
#  ('2_p', 'R'): 0,
#  ('1_p', 'R'): 0}

# %%
print_final_flows(G_k)
# Out:
# ('1', '2')  :  8.652449223434267
# ('1', 'R')  :  2.8717734685546596
# ('1', '2_p')  :  1.3475507765657389
# ('1', '1_p')  :  5.75904709708364
# ('2', '1')  :  8.630832205064124
# ('2', '2_p')  :  8.652449223434267
# ('2', '1_p')  :  4.240952902916363
# ('2', 'R')  :  2.8075260572391993

# %%
print_final_cost(G_k)
# Out:
# ('1', '2')  :  39.02279202424334
# ('1', 'R')  :  41.34468853614555
# ('1', '2_p')  :  90.0
# ('1', '1_p')  :  51.024038738084286
# ('2', '1')  :  39.01247560661808
# ('2', '2_p')  :  50.91842005238689
# ('2', '1_p')  :  90.0
# ('2', 'R')  :  10000000000000000000000

# %%
sanity_check_N(G_k)
# Out:
# 1 to 2:  10.000000000000007
# 2 to 1:  10.000000000000004

# %%
sanity_check_cost(G_k)
# Out:
# 1 to 2:  90.0  =====  89.94121207663022
# 2 to 1:  90.0  =====  90.03651434470237

# %%
plot_errors(G_k,'log',dots=False,lims=None)

# %% [markdown]
# Interesting: it seems to do the right thing and make really good progress to attaining the objective, but at some stage it becomes erratic and no progress at all is being made.
#
# I am assuming the problem comes from the rebalancers changing relatively often. difficult to go beyond a certain level of accuracy apparently.
#
# To be noted: the oscillations are on both sides of the equilibrium point (i.e. negative and positive). That means you go on both sides of the cost.

# %% [markdown]
# ### Analyze output

# %%
#plot also the theoretical lines (what should the result be, theoretically?)

# %%
attrs=['f_m', 'f_r','cost','k', 'y_m','y_r']
attrs=['f_m','f_r']
plot_edge_attrs(G_k,y_list,attrs,dots=False,lims=[1500,1550])

# %%
#this is equivalent to plotting the OD pairs at least for the rebalancers
plot_node_attrs(G_k,['ri'])

# %% [markdown]
# The total cost increases logically, as it involves additional flow (rebalancing flow) that was not there in the beginning

# %%
plt.figure(figsize=(10,5))
plt.plot(np.array(opt_res['obj']),'--')
plt.grid(True)
plt.ylabel("obj value")
plt.xlabel("iteration #")
# Out:
# Text(0.5, 0, 'iteration #')

# %%
plt.figure(figsize=(10,5))
plt.plot(np.array(opt_res['a_k']),'--')
plt.grid(True)
plt.ylabel("a_k")
plt.xlabel("iteration #")
plt.yscale('log')

# %% [markdown]
# # Understand the oscillations around 0

# %% [markdown]
# Why does the error keep oscillating while the assignments are nearly the same?
# The assignment barely budge after iteration 25, while this is when the error starts oscillating.

# %%
lims=[1500,1600]

# %%
analyze_cost_oscillations(G_k,'1','2',lims,'log')

# %%
analyze_cost_oscillations(G_k,'2','1',lims,'log')

# %%
analyze_cost_oscillations_2(G_k,'1','2',lims)

# %%
analyze_cost_oscillations_2(G_k,'2','1',lims)

# %%
analyze_cost_oscillations_3(G_k,y_list,'1','2',lims)
# Out:
# Black lines indicate that the assignment variable y_m is activated for the dummy edge

# %%
analyze_cost_oscillations_3(G_k,y_list,'2','1',lims)
# Out:
# Black lines indicate that the assignment variable y_m is activated for the dummy edge

# %% [markdown]
# # LET US ANALYZE THE SIZE OF JUMPS IN FLOW ON THE DUMMY EDGE

# %% [markdown]
# ## Dummy edge 1 2p

# %%
y_m=[]
for G in G_k:
    y_m.append(G['1']['2_p']['f_m'])
y_m=np.array(y_m)

# %%
diff_y_m=[]
for i in range(y_m.shape[0]-1):
    diff_y_m.append(y_m[i+1]-y_m[i])
diff_y_m=np.array(diff_y_m)

# %%
jumps=diff_y_m[diff_y_m>0]

# %%
len(jumps)
# Out:
# 276

# %%
y_m.shape[0]/len(jumps)
# Out:
# 7.246376811594203

# %% [markdown]
# one jump every 7 or 8 steps makes sense

# %%
plt.figure(figsize=(13,5))
plt.plot(jumps)
plt.yscale('log')
plt.grid(True)

# %% [markdown]
# We see that the size of jumps is directly correlated with alpha, as expected.
# Therefore, two possiblities: either change alpha or change the size of the steps (we increase everytime by a significant amount, and that is not efficient)
# There are clues in Gardner paper in order to make the bound updating

# %% [markdown]
# Just like in Gartner paper: he was saying if we update the size of the steps (i.e. the upper bounds and lower bounds on potential demand, we reach the optimum much faster).
# This also eliminates the need for line search, which is pretty positive.

# %% [markdown]
# # Routines to implement

# %%
# def stopping_criterion(x_k,y_k):

# %% [markdown]
# # Useful nx lines

# %%
nx.get_edge_attributes(G,'f')
# Out:
# {('1', '2'): 0, ('1', 'R'): 0, ('2', '1'): 0, ('2', '2_p'): 0}

# %%
G.nodes.data()
# Out:
# NodeDataView({'1': {}, '2': {}, '2_p': {'pot': 90}, 'R': {}})

# %%
G.edges.data()
# Out:
# OutEdgeDataView([('1', '2', {'k': 1, 'phi': 36.0, 'sign': 1, 'f': 0, 'cost': 36.0}), ('1', 'R', {'k': 10, 'phi': 36.0, 'sign': 1, 'f': 0, 'cost': 36.0}), ('2', '1', {'k': 10, 'phi': 36.0, 'sign': 1, 'f': 0, 'cost': 36.0}), ('2', '2_p', {'k': 10, 'phi': 36.0, 'sign': -1, 'f': 0, 'cost': -36.0})])

# %%
G['1']['2']
# Out:
# {'f': 0, 'k': 1, 'phi': 36.0, 'sign': 1, 'cost': 36.0}
